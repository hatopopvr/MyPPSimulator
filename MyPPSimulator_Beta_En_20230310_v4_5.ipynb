# %% [markdown]
# <a href="https://colab.research.google.com/github/hatopopvr/MyPPSimulator/blob/main/MyPPSimulator_Beta_En_20230310_v4_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MyPPSimulator_Beta_En
#
# <b>Data</b>
# - Score Data from ScoreSaber Public API - [doc](https://docs.scoresaber.com/)
# - Ranked Map Data from RankedMapData by rakkyo150 - [RankedMapData](https://github.com/rakkyo150/RankedMapData)
#
# <b>Author</b>
# - hatopop ([@hatopop_vr](https://twitter.com/hatopop_vr))
#
# <b>Caution</b>
# - If you would like me to add a default value for the timezone, please mentions me on Twitter.

# %%
#@title # Caution [EN]

#@markdown ### <strong>This tool is currently in beta version</strong>

#@markdown We plan to add and improve features and consolidate the steps for the official release. Please understand that there may be some rough edges and incomplete steps in the beta version.

#@markdown The current beta version includes the following features:

#@markdown - [New] Acc Prediction Model
#@markdown - [New] S2: Playlist Simulation
#@markdown - [Existing] Automatic setting function for ★ range and PP target value

#@markdown ### <strong>Acc Prediction Model</strong>
#@markdown The Acc Prediction Model allows users to build a model that predicts their accuracy based on their scores and correct answer rates. Here, users do not need to adjust settings in most cases. By using My Stats & Range, users can obtain reference information to set the range of ★ (difficulty) that they mainly play to obtain scores (PP). Please refer to the output of Build My Acc Prediction Model to check the performance of the model's Acc prediction.

#@markdown ### <strong>S2: Playlist Simulation</strong>
#@markdown In S2's Playlist Simulation (Target), users can create a playlist of songs that are likely to yield PP by extracting only the songs that the user can obtain a predicted accuracy based on the songs that players with a similar Total PP are playing. In addition, in S2's Playlist Simulation (Without Target Player Data), users can create a playlist of songs that are likely to yield PP by extracting only the songs that the user can obtain a predicted accuracy based on all ranked songs. By simulating how many misses to reduce, users can also reflect the possible PP values that can be obtained.

#@markdown If the caution note is in the way during use, please feel free to delete the caution note cell.

#@markdown For bug reports or improvement requests, please contact [@hatopop_vr](https://twitter.com/hatopop_vr).

# %%
#@title # 注意事項 [JP]


#@markdown ### <strong>このツールは現在Beta版です。</strong>
#@markdown 今後、機能の追加や改善を行い、手順を整備して正式版に反映する予定です。Beta版につき、手順等整備できていないことをご了承ください。

#@markdown 現在のBeta版では、以下の機能が追加されています。
#@markdown - [新規] Acc Prediction Model
#@markdown - [新規] S2: Playlist Simulation
#@markdown - [既存] ★範囲やPP目標値の自動設定機能

#@markdown ### <strong>Acc Prediction Model</strong>
#@markdown Acc Prediction Modelは、スコアと正答率に基づいてユーザーの正確さを予測するモデルを構築することができます。My Stats & Rangeを使用することで、ユーザーはスコア（PP）を取得するために主にプレイする★（難易度）の範囲を設定するための参考情報を取得できます。基本的に、ユーザーは設定を弄る必要はありません。モデルのAcc予測のパフォーマンスを確認するには、Build My Acc Prediction Modelの出力を参照してください。

#@markdown ### <strong>S2: Playlist Simulation</strong>
#@markdown Playlist Simulation (Target)では、Get Target Players Dataにて、目的のTotal PP付近のプレイヤーがプレイしている譜面をリストアップし、その中で自分が取得可能なAccを予測することで、PPを得ることが可能と推測される譜面だけを抽出し、プレイリストを作成することができます。また、Playlist Simulation (Without Target Player Data)では、全てのランク譜面から自分が取得可能なAccを予測することで、PPを得ることが可能と推測される譜面だけを抽出し、プレイリストを作成することができます。それぞれ、ミス数をいくつ減らすかなどをシミュレーションすることで、獲得可能なPP値も反映させることができます。

#@markdown また、使用時に注記が邪魔な場合は、注記のセルを削除してください。

#@markdown バグ報告や改善要望については、[@hatopop_vr](https://twitter.com/hatopop_vr) までご連絡ください。

# %%
#@title # Input Information
#@markdown ---
#@markdown <h4>Input Data</h4>

#@markdown <font size="3">`player_id` : PlayerID for ScoreSaber. <b>Must</b> be changed.<br/></font>  
player_id =  76561198412839195#@param {type:"number"}

#markdown <font size="3">`google_drive_mount_path` ：GoogleDriveのマウント先です。変更不要。</font><br/> 
google_drive_mount_path = "/content/drive" #param {type:"string"}

#@markdown <font size="3">`google_drive_dir_path` : The directory to save data in GoogleDrive. Optional change.</font> 
google_drive_dir_path = "/MyDrive/MyBeatSaberAnalysis/data" #@param {type:"string"}

#@markdown ---
#@markdown <h4>Setting</h4>

#@markdown <font size="3">`saved_player_score_is_enable`: Whether to use saved score data. Download only the difference.</font>
saved_player_score_is_enable = True #@param {type:"boolean"}
#@markdown <font size="3">`acc_recalq_override_is_enable`: Whether to use the recalculated Accuracy value based on the number of Notes and Combo.</font> 
acc_recalq_override_is_enable = True #@param {type:"boolean"}
# #@markdown <font size="3">`beatleader_data_is_enable`: Whether to retrieve and use data from beatleader.</font>
# beatleader_data_is_enable = True #@param {type:"boolean"}
#markdown <font size="3">`ranked_song_form_leaderboard_is_enable`: Ranked譜面クリア進捗用のレベル別譜面数をScoreSaberのLeaderBoardから取得し直すか。☑で使用。<br /></font>
ranked_song_from_leaderboard_is_enable = False 
#markdown <font size="3">`ss_plus_is_enable`: AccRank区分にSS+を使用するか。☑で使用。  </font><br /> 
ss_plus_is_enable = True #param {type:"boolean"}
#markdown <font size="3">`ss_plus_val`:SS+の設定値です。必要に応じて変更ください。範囲は91-99。  
ss_plus_val = 95 #param {type:"slider", min:91, max:99, step:1}
#@markdown <font size="3">`Recent`:The number of days to be treated as the most recent results. 0 is the same date as today in timezone. If 1, from yesterday.
Recent =  1#@param {type:"integer"}

#@markdown <font size="3">`timezone`:Input or Select your timezone.<br />
#@markdown <font size="3"> The following URL can be used as a reference for time zones ([mjrulesamrat/countryinfo.py](https://gist.github.com/mjrulesamrat/0c1f7de951d3c508fb3a20b4b0b33a98))
timezone = "Asia/Tokyo" #@param ["Asia/Tokyo", "US/Pacific", ""] {allow-input: true}
#@markdown <font size="3">`score_mode`:Select the score you want to get, where `HigherScore` is the higher of `BaseScore` and `ModifieredScore`.</font>
score_mode = "HigherScore" #@param ["BaseScore", "ModifieredScore", "HigherScore"]

#@markdown <font size="3">`c`:PP-curve parameter. Basically, don't touch it. default value:`42.113`</font>
c = 42.113 #@param {type:"number"}

#@title Libraryの取得
# !pip install GitPython
import warnings
warnings.filterwarnings("ignore")
import os
import shutil
import pandas as pd
from pandas import json_normalize
import json
from datetime import datetime, timedelta
from dateutil import tz
import plotly.express as px
from ipywidgets import interact, Select, BoundedIntText, IntSlider, ToggleButtons, Layout, HBox, VBox, AppLayout
import time
from tqdm import tqdm
import requests
import math
import git
import gc
from IPython.display import HTML, Javascript,Image
from google.colab import drive, files
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import copy
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from scipy import interpolate

#@title Timezone UTC->日本時間+9:00での実行日時の取得(tz_ja)
# tz_ja = pd.Timestamp(datetime.now()).tz_localize('UTC').tz_convert('Asia/Tokyo')
tz_ja = pd.Timestamp(datetime.now()).tz_localize('UTC').tz_convert(timezone)
#today_tz_ja = datetime_now_tz_ja.strftime("%Y.%m.%d")
# print("get_date:{} timezone:{}".format(tz_ja, timezone))
#@title Google Driveのマウント
drive.mount(google_drive_mount_path)

#@title その他内部設定値
# データ元のURL
## song_data_zip_git_url: ScoreSaberの全曲情報のzip(json)のURLです。変更なければそのままで。 
song_data_zip_git_url = "https://github.com/andruzzzhka/BeatSaberScrappedData.git"
## ranked_excluded_data_git_url: ScoreSaberのRank譜面除外リスト(csv)のURLです。暫定的処置。 
ranked_excluded_data_git_url = "https://github.com/hatopopvr/ScoreSaberRankedExcludedMaps.git"
## rankedmapdata_url: BeatSaverデータのcsvのURLです。らっきょさんデータ。 
rankedmapdata_url = 'https://api.github.com/repos/rakkyo150/RankedMapData/releases'
# google drive内のdata置き場親フォルダ
data_path = r"{}{}".format(google_drive_mount_path, google_drive_dir_path)
# player情報の親フォルダ(data_pathの子フォルダ)
player_path = r"{}/players_data/{}".format(data_path, player_id)
## playerinfoの保存先
player_info_path = r"{}/player_info_{}.csv".format(player_path, player_id)
## playerのscore関連保存先
player_score_path = r"{}/scores_full_{}.csv".format(player_path, player_id)
player_ranked_path = r"{}/scores_ranked_{}.csv".format(player_path, player_id)
## playerのscore関連保存先
player_score_pickle_path = r"{}/scores_full_{}.pkl".format(player_path, player_id)
player_ranked_pickle_path = r"{}/scores_ranked_{}.pkl".format(player_path, player_id)
## 曲情報の保存関連
song_clone_path = r"/content/BeatSaberScrappedData"
song_zip_path = r"{}/combinedScrappedData.zip".format(song_clone_path)
song_json_path = r"{}/combinedScrappedData.json".format(data_path)
## 曲情報の保存先
song_list_path = r"{}/song_list_full.csv".format(data_path)
song_ranked_path = r"{}/song_ranked.csv".format(data_path)
# ランク除外関連パス
ranked_excluded_clone_dir_path = r"/content/ScoreSaberRankedExcludedMaps"
ranked_excluded_clone_csv_path = r"{}/RankedExcludedMaps.csv".format(ranked_excluded_clone_dir_path)
ranked_excluded_csv_path = r"{}/RankedExcludedMaps.csv".format(data_path)
# levelclearランク除外関連パス
level_cleared_path = r"{}/level_cleared_{}.csv".format(player_path, player_id)

# playlistの保存
song_playlist_path = r"{}/playlists".format(data_path)
song_worst_playlist_path = r"{}/worst_playlist_{}.json".format(song_playlist_path, tz_ja.strftime("%Y%m%d"))
song_top_playlist_path = r"{}/top_playlist_{}.json".format(song_playlist_path, tz_ja.strftime("%Y%m%d"))

# SS_plus設定値
ss_plus = "SS+{}".format(ss_plus_val)
ss_plus_rate = "SS+{}-Rate".format(ss_plus_val)
# その他 colab表示など設定
pd.options.display.precision = 2
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
page_count=100 #ScoreSaberの1ページあたりのページ数

# 出力最大高さ
def resize_colab_cell():
    display(Javascript('google.colab.output.setIframeHeight(0, true, {maxHeight: 5000})'))

get_ipython().events.register('pre_run_cell', resize_colab_cell)

#@title 列情報の設定
# Player Infoの記録用列 (TotalFC, RankedFCは別途結合)
cols_info =[
    "Pic"
    ,"name"
    ,"country"
    ,"pp"
    ,"rank"
    ,"countryRank"
    ,"role"
    ,"TotalScore"
    ,"RankedScore"
    ,"AveRankedAcc"
    ,"TotalPlay"
    ,"RankedPlay"
    ,"ReplayWatched"
    ,"ScoreDate"
    ,"TotalFC"
    ,"RankedFC"
    ,"TotalPlayRank"
    ,"TotalPlayJPRank" 
    ,"RankedPlayRank"
    ,"RankedPlayJPRank"
    ,"TotalScoreRank" 
    ,"TotalScoreJPRank"
    ,"RankedScoreRank"
    ,"RankedScoreJPRank" 
    ,"AveRankedAccRank"
    ,"AveRankedAccJPRank"
]

# Player Infoの表示用列 (TotalFC, RankedFCは別途結合)
cols_info_sort =[
    "Pic"
    ,"name"
    ,"country"
    ,"pp"
    ,"rank"
    ,"countryRank"
    ,"role"
    ,"TotalScore"
    ,"RankedScore"
    ,"AveRankedAcc"
    ,"TotalPlay"
    ,"RankedPlay"
    ,"TotalFC"
    ,"RankedFC"
    ,"ReplayWatched"
    ,"ScoreDateTz"
]

# リュナンさんのScoreSaberRanking表示用列(不使用)
cols_info_rank = [
    "TotalPlayRank"
    ,"TotalPlayJPRank" 
    ,"RankedPlayRank"
    ,"RankedPlayJPRank"
    ,"TotalScoreRank" 
    ,"TotalScoreJPRank"
    ,"RankedScoreRank"
    ,"RankedScoreJPRank" 
    ,"AveRankedAccRank"
    ,"AveRankedAccJPRank"
]

# summary用列
cols_summary =[
    "rank"
    ,"countryRank"
    ,"pp"
    ,"AveRankedAcc"
    ,"TotalPlay"
    ,"RankedPlay"
]

# SongList抜粋用列
cols_song =[
    "Cover"
    ,"Song"
    ,"Level"
    ,"LevelStr"
    ,"Stars"
    # ,"maxPP"
    # ,"maxScore"
    ,"Difficulty"
    # ,"Play"
    # ,"DailyPlay"
    ,"CreatedDateJa"
    ,"RankDateJa"
    ,"Bombs"
    ,"Notes"
    ,"Obstacles"
    ,"Njs"
    ,"NjsOffset"
    ,"Bpm"
    ,"Upvotes"
    #,"Downvotes"
    ,"Duration"
    ,"Ranked"
]

# Rank譜面除外リスト結合用列
cols_excluded = [
                 'Hash',
                 'Difficulty',
                 'RankedExcluded'
                 ]

# Score用列
cols_score =[
    "Cover"
    ,"Song"
    ,"Level"
    ,"Stars"
    ,"Acc"
    ,"AccRank"
    ,"FC"
    ,"Rank"
    ,"PP"
    ,"Miss"
    ,"Bad"
    ,"Combo"
    ,"Score"
    #,"Mode"
    ,"Difficulty"
    ,"Play"
    ,"DailyPlay"
    ,"Bpm"
    ,"Duration"
    ,"Notes"
    ,'Nps'
    ,"Njs"
    ,"Bombs"
    ,"Obstacles"
    # ,"NjsOffset"
    ,'Upvotesratio' 
    ,"Upvotes"
    ,"Downvotes"
    ,"Ranked"
    ,"Days"
    ,"Months"
    ,"Tags"
    ,"Preview"
 ]

# Acc再計算用列
cols_recalq = [
    'Hash',
    'Cover',
    'SongName',
    'Difficulty', 'Stars', 
    # 'Ranked', 
    'Notes', 
    'Acc', 
    'AccRecalq', 
    'AccDiff',
    'AccRank', 
    'AccRankRecalq', 
    'MaxScore',
    'MaxScoreRecalq',
    'MaxScoreDiff',
    'Score', 
    'Miss', 
    'Combo',
    # 'RankDateJa',
    # 'CreatedDateJa', 
    'Preview'
]

# ScatterPlot用X-Y軸列
cols_xy = [
    "Stars"
    ,"Level"
    ,"Acc"
    ,"Rank"
    ,"PP"
    ,"Miss"
    ,"Bad"
    ,"Combo"
    ,"Score"
    ,"Play"
    ,"DailyPlay"
    ,"Days"
    ,"Months"
    ,"Bpm"
    ,"Duration"
    ,"Notes"
    ,'Nps'
    ,"Njs"
    ,"Bombs"
    ,"Obstacles"
    ,"NjsOffset"
    ,'Upvotesratio'
    ,"Upvotes"
    ,"Downvotes"
]

# RankedMap(BeatSaver)結合用列
cols_rankedmap = ['Hash', 
                  'Difficulty', 
                  'Upvotesratio',
                  'Nps', 
                  'Tags', 'Preview'
]

# ScatterPlot用カテゴリ
cols_cate = [
    "LevelStr"
    ,"Days"
    ,"DaysStr"
    ,"Months"
    ,"MonthsStr"
    ,"RecentStr"
    ,"Acc"
    ,"AccRank"
    ,"FC"
    ,"SongAuthor"
    ,"LevelAuthor"
]

# Worst-Top ScatterPlot用カテゴリ
cols_cate_wt = [
    "WorstTop"
    ,"LevelStr"
    ,"Days"
    ,"DaysStr"
    ,"Months"
    ,"MonthsStr"
    ,"RecentStr"
    ,"Acc"
    ,"AccRank"
    ,"FC"
    ,"SongAuthor"
    ,"LevelAuthor"
]

# Recent_history用の列
cols_Recent_history = ['Cover', 'Song', 'Difficulty', 'Stars', 'Acc', 'AccRank', 'FC', 'Rank', 'PP',
       'Miss', 'Bad', 'Combo', 'Score']


cols_worst_n = ['Cover', 'Song', 'Difficulty', 'Level', 'Stars', 'Acc', 'AccRank', 'FC', 'Rank', 'PP',
       'Miss', 'Bad', 'Combo', 'Score']

#@title スタイルの設定

cover_image_size=70 #カバー,プロファイル画像のサイズ単位px
info_image_size=150 #Player画像のサイズ単位px

style_format = {
        "rank": "#{:,.0f}",
        "countryRank": "#{:,.0f}",
        "TotalScore": "{:,.0f}",
        "RankedScore": "{:,.0f}",
        "AveRankedAcc": "{:,.2f}%",
        "TotalPlay": "{:,.0f}",
        "RankedPlay": "{:,.0f}",
        "TotalFC": "{:,.0f}",
        "RankedFC": "{:,.0f}",
        "ReplayWatched": "{:,.0f}",
        "Level": "{:,.0f}",
        "Stars": "{:,.2f}★",
        "Acc": "{:,.2f}%",
        "AccRecalq": "{:,.2f}%",
        "AccDiff": "{:,.2f}%",
        "MaxScore": "{:,.0f}",
        "MaxScoreRecalq": "{:,.0f}",
        "MaxScoreDiff": "{:,.0f}",
        "Score": "{:,.0f}",
        "Rank": "#{:,.0f}",
        "pp": "{:,.2f}pp",
        "PP": "{:,.2f}pp",
        "Miss": "{:,.0f}",
        "Bad": "{:,.0f}",
        "Combo": "{:,.0f}",
        "Score": "{:,.0f}",
        "Play": "{:,.0f}",
        "DailyPlay": "{:,.0f}",
        "Bpm": "{:,.0f}",
        "Duration": "{:,.0f}",
        "Notes": "{:,.0f}",
        "Nps": "{:,.2f}",
        "Njs": "{:,.0f}",
        "Bombs": "{:,.0f}",
        "Obstacles": "{:,.0f}",
        "NjsOffset": "{:,.2f}",
        "Upvotesratio": "{:,.2f}",
        "Upvotes": "{:,.0f}",
        "Downvotes": "{:,.0f}",
        "Days": "{:,.0f}",
        "Months": "{:,.0f}",
        "Song": "{:,.0f}",
        "RecentCleared": "{:,.0f}",
        "Cleared": "{:,.0f}",
        "NF": "{:,.0f}",
        "NotCleared": "{:,.0f}",
        "AlreadyCleared": "{:,.0f}",
        "NotClearedRate": "{:,.2f}%",
        "AlreadyClearedRate": "{:,.2f}%",
        "RecentClearedRate": "{:,.2f}%",
        "NFRate": "{:,.2f}%",
        "SSS": "{:,.0f}",
        ss_plus: "{:,.0f}",
        "SS": "{:,.0f}",
        "S": "{:,.0f}",
        "A": "{:,.0f}",
        "B": "{:,.0f}",
        "Other": "{:,.0f}",
        "SSS-Rate": "{:,.2f}%",
        "SS-Rate": "{:,.2f}%",
        ss_plus_rate: "{:,.2f}%",
        "S-Rate": "{:,.2f}%",
        "A-Rate": "{:,.2f}%",
        "B-Rate": "{:,.2f}%",
        "Other-Rate": "{:,.2f}%",
        "FC": "{:,.0f}",
        "RecentFC": "{:,.0f}",
        "AlreadyFC": "{:,.0f}",
        "NotFC": "{:,.0f}",
        "AlreadyFCRate": "{:,.2f}%",
        "RecentFCRate": "{:,.2f}%",
        "NotFCRate": "{:,.2f}%",
        "Song": "{:,.0f}",
        "TotalPlayRank": "#{:,.0f}",
        "TotalPlayJPRank": "#{:,.0f}",
        "RankedPlayRank": "#{:,.0f}",
        "RankedPlayJPRank": "#{:,.0f}",
        "TotalScoreRank": "#{:,.0f}",
        "TotalScoreJPRank": "#{:,.0f}",
        "RankedScoreRank": "#{:,.0f}",
        "RankedScoreJPRank": "#{:,.0f}",
        "AveRankedAccRank": "#{:,.0f}",
        "AveRankedAccJPRank": "#{:,.0f}",
     }

ss_plus = "SS+{}".format(ss_plus_val)
ss_plus_rate = "SS+{}-Rate".format(ss_plus_val)

style_worst_top = {
        "Level": "{:,.0f}",
        "Stars": "{:,.2f}★",
        "Acc": "{:,.2f}%",
        "Rank": "#{:,.0f}",
        "pp": "{:,.2f}pp",
        "PP": "{:,.2f}pp",
        "Miss": "{:,.0f}",
        "Bad": "{:,.0f}",
        "Combo": "{:,.0f}",
        "Score": "{:,.0f}",
        "Play": "{:,.0f}",
        "DailyPlay": "{:,.0f}",
        "Bpm": "{:,.0f}",
        "Duration": "{:,.0f}",
        "Notes": "{:,.0f}",
        "Nps": "{:,.2f}",
        "Njs": "{:,.0f}",
        "Bombs": "{:,.0f}",
        "Obstacles": "{:,.0f}",
        "NjsOffset": "{:,.2f}",
        "Upvotesratio": "{:,.2f}",
        "Upvotes": "{:,.0f}",
        "Downvotes": "{:,.0f}",
        "Days": "{:,.0f}",
        "Months": "{:,.0f}",
     }

def color_negative_red(val):
    color = 'red' if val < 0 else 'blue'
    return 'color: %s' % color

# Difficulty color
def color_difficulty(val):
    if val == "Easy":
        return 'color: #66BB6A; font-weight: bold;'
        color = "#66BB6A"
    elif val == "Normal":
        return 'color: #29B6F6; font-weight: bold;'
        color = "#29B6F6"
    elif val == "Hard":
        return 'color: #FB8C00; font-weight: bold;'
        color = "#FB8C00"
    elif val == "Expert":
        return 'color: #E53935; font-weight: bold;'
        color = "#E53935"
    elif val == "Expert+":
        return 'color: #8E24AA; font-weight: bold;'
        color = "#8E24AA"
    elif val == "ExpertPlus":
        return 'color: #8E24AA; font-weight: bold;'
        color = "#8E24AA"
    return 'color: %s' % color

# Acc Rank color
def color_acc_rank(val):
    if val == "SSS":
        return 'color: #00ffff; font-weight: bold;'
    elif ss_plus_is_enable and val == ss_plus:
        return 'color: #636EFA; font-weight: bold;'
    elif val == "SS":
        return 'color: #ff4500; font-weight: bold;'
    elif val == "S":
        return 'color: #ffaaff; font-weight: bold;'
    elif val == "A":
        return 'color: #ffcc66; font-weight: bold;'
        #color = "#eebb55"
    elif val == "B":
        return 'color: #cccc66; font-weight: bold;'
    else:
        return 'color: #666666; font-weight: bold;'
    # return 'color: %s' % color


# Acc Rank color
def color_acc_player(val):
    if val == 100:
        return 'color: #00ffff; font-weight: bold;'
    elif ss_plus_is_enable and val >= ss_plus_val:
        return 'color: #636EFA; font-weight: bold;'
    elif val >= 90:
        return 'color: #ff4500; font-weight: bold;'
    elif val == 80:
        return 'color: #ffaaff; font-weight: bold;'
    elif val == 65:
        return 'color: #ffcc66; font-weight: bold;'
        #color = "#eebb55"
    elif val == 50:
        return 'color: #cccc66; font-weight: bold;'
    else:
        return 'color: #666666; font-weight: bold;'
    # return 'color: %s' % color


# FC color
def color_fc(val):
    if val == "FC":
        color = "#23D160"
    else:
        color = "black"        
    return 'color: %s' % color

def color_fc(val):
    if val == "FC":
        return 'color: #23D160; font-weight: bold;'
    else:
        return 'color: black'


# Player Info Table Format
styles_info = [
    dict(selector="td", props=[("font-size", "130%"),
                               ("text-align", "center"),
                               ("padding-top", "0px"),
                               ("padding-bottom", "0px"),                              
                               ])
]

# Player Info Table Format
styles_data = [
    {"selector":"td", "props":[("padding-top", "0px"),
                               ("padding-bottom", "0px"),                              
                               ]},
    {"selector":"th", "props":[("padding-top", "0px"),
                               ("padding-bottom", "0px"),                              
                               ]},
]

# Caption Table Format
caption_styles = [dict(selector="caption",
                       props=[
                              ("text-align", "lett"),
                              ("font-size", "150%"),
                              ("border-bottom", "1px solid"),
                              ]
                       )
                  ]


# pp curve
curve = [
   [1, 7],
   [0.999, 6.24],
   [0.9975, 5.31],
   [0.995, 4.14],
   [0.9925, 3.31],
   [0.99, 2.73],
   [0.9875, 2.31],
   [0.985, 2.0],
   [0.9825, 1.775],
   [0.98, 1.625],
   [0.9775, 1.515],
   [0.975, 1.43],
   [0.9725, 1.36],
   [0.97, 1.3],
   [0.965, 1.195],
   [0.96, 1.115],
   [0.955, 1.05],
   [0.95, 1],
   [0.94, 0.94],
   [0.93, 0.885],
   [0.92, 0.835],
   [0.91, 0.79],
   [0.9, 0.75],
   [0.875, 0.655],
   [0.85, 0.57],
   [0.825, 0.51],
   [0.8, 0.47],
   [0.75, 0.4],
   [0.7, 0.34],
   [0.65, 0.29],
   [0.6, 0.25],
#    [0.0, 0.0],
   [0.0001, 0.0001],#0での除算対応
]

curve_y_acc = [curve[i][0] * 100 for i in range(len(curve))]
curve_c = [curve[i][1] for i in range(len(curve))]

# タイムゾーンの設定-------------------------


#@title 各種フォルダの作成
# 各種パスのディレクトリ作成
## データ大元のフォルダ作成
if os.path.exists(data_path) == False:
    print('MyBeatSaberAnalytics用のデータ格納フォルダをGoogle Driveに新規作成します。')
    print('データ格納フォルダ:{}'.format(data_path))     
    os.makedirs(data_path, exist_ok=True)
    print('作成が完了しました。')         

## データ大元のフォルダ作成
if os.path.exists(player_path) == False:
    old_player_info_path = r"{}/player_info_{}.csv".format(data_path, player_id)
    print('PlayerID:{}用のデータ格納フォルダを新規作成します。'.format(player_id))
    print('playerフォルダ:{}'.format(player_path))     
    print('作成が完了しました。')         
    os.makedirs(player_path, exist_ok=True)
    if os.path.isfile(old_player_info_path):
        print('データ引継ぎのため、player_infoｂのcsvファイルを上記フォルダに移動させます。')
        print('移動前:{}'.format(old_player_info_path))
        print('移動後:{}'.format(player_info_path))
        shutil.move(old_player_info_path, player_info_path)
        print('移動が完了しました。')

## プレイヤー用のフォルダ作成
if os.path.exists(song_playlist_path) == False:
    print('Playlist格納用のフォルダを新規作成します。')
    print('Playlist格納フォルダ:{}'.format(song_playlist_path))     
    os.makedirs(song_playlist_path, exist_ok=True)
    print('作成が完了しました。')

#@title Get Player Info (df_info)
url = r"https://scoresaber.com/api/player/{}/full".format(player_id)
response = requests.get(url)
res_data = response.json()
df_info = json_normalize(res_data)

#df_info["Pic"] = '<img src="'+df_info["profilePicture"]+'"/>'
df_info["Pic"] = '<img src="'+df_info["profilePicture"]+'" style="width:{}px;"/>'.format(info_image_size)
df_info["TotalScore"] = df_info["scoreStats.totalScore"]
df_info["RankedScore"] = df_info["scoreStats.totalRankedScore"]
df_info["AveRankedAcc"] = df_info["scoreStats.averageRankedAccuracy"]
df_info["TotalPlay"] = df_info["scoreStats.totalPlayCount"]
df_info["RankedPlay"] = df_info["scoreStats.rankedPlayCount"]
df_info["ReplayWatched"] = df_info["scoreStats.replaysWatched"]
df_info["ScoreDate"] = datetime.now().strftime("%Y/%m/%d %H:%M:%S")

df_info["ScoreDateUtc"] = pd.to_datetime(df_info['ScoreDate'], utc=True)
_df_info_idx = df_info.set_index("ScoreDateUtc")
df_info["ScoreDateTz"] = _df_info_idx.index.tz_convert(timezone)

PlayCount = df_info["TotalPlay"][0]
RankedPlay = df_info["RankedPlay"][0]
RangeCount = math.ceil(PlayCount / page_count) + 1

print("------------------------------------")
print("timezone:{} | datetime:{} ".format(timezone, tz_ja))
# print("Player:{}, TotalPlayCount:{:,}, RankedPlayCount:{:,}, PageCount:{}".format(df_info["name"][0], PlayCount, RankedPlay, RangeCount))

# display(df_info[['Pic','name','TotalPlay']].style.set_table_styles(styles_info).format(style_format, na_rep="-"))

# ----------------------------------------
# Display Player Information
# ----------------------------------------
def str_difficulty(val):
    if val == "Easy":
        return 'E'
    elif val == "Normal":
        return 'N'
    elif val == "Hard":
        return 'H'
    elif val == "Expert":
        return 'Ex'
    elif val == "Expert+":
        return 'Ex+'
    elif val == "ExpertPlus":
        return 'Ex+'
    return '-'

def str_fc(val):
    if val == "FC":
        return 'FC'
    else:
        return ''

# FC color
def color_fc(val):
    if val == "FC":
        color = "#23D160"
    else:
        color = "black"        
    return 'color: %s' % color

# pp color
def color_pp(val):
    if val >= target_pp:
        color = "red"
    else:
        color = "black"        
    return 'color: %s' % color

# rank color
def color_rank(val):
    if val <= target_global_rank:
        color = "red"
    else:
        color = "black"        
    return 'color: %s' % color

def color_latest(x):
    if  x == 1:
        color = "red"
    else:
        color = "black"        
    return 'color: %s' % color

# weight
def format_weight(val):
    if val <= target_weight:
        return "".format(val)
    else:
        return "({:.1f}pp)".format(val)

def format_star(val):
    if val > 0:
        return "{:.2f}★".format(val)
    else:
        return ""
    return "{:.2f}★".format(val)        

def format_acc(val):
    if val <= 100:
        return "{:.2f}%".format(val)
    else:
        return ""
    return "{:.2f}%".format(val)

def format_pp(val):
    if val > 0:
        return "{:.1f}pp".format(val)
    else:
        return ""
    return "{:.1f}pp".format(val)

def func_unrank(x):
    if x == 0:
        return None
    else:
        return x

def func_tile_css(_width=1000,
             _cover_image_size=200,
             _star_font_size=22,
             _diff_font_size=18,
             _acc_font_size=18,
             _fc_font_size=18,
             _pp_font_size=22,
             _weight_font_size=8,
             _rank_font_size=22,
             _date_font_size=18,
             _player_font_size=22,
             _notes_acc_font_size=24
             ):
    return """
        <style>
        .flex_box {
            width:""" + str(_width) + """px;
            display: flex; /* フレックスボックスにする */;
            flex-wrap: wrap;
            padding:0px;
            margin:0px;
        }
        .flex_item {
            display: inline-block;
            position: relative;
            padding:0px 5px 0px 0px;
            margin:0px;
        }
        .flex_str_top, .flex_str_bottom_left, .flex_str_bottom_right{
            position: absolute;
            font-weight: bold;
            white-space:nowrap;
            overflow:hidden;
            color: #000;
            width:""" + str(_cover_image_size-10) + """px;
            text-shadow:1px 1px 0 #FFF, -1px -1px 0 #FFF,
                    -1px 1px 0 #FFF, 1px -1px 0 #FFF,
                    0px 1px 0 #FFF,  0-1px 0 #FFF,
                    -1px 0 0 #FFF, 1px 0 0 #FFF;
        }

        .flex_str_top {
            left: 5px;
            top: 5px;
        }

        .flex_str_bottom_left {
            left: 5px;
            bottom: 5px;
        }

        .flex_str_bottom_right {
            left: 5px;
            bottom: 5px;
        }

        .flex_star, .flex_acc, .flex_accrank, .flex_fc ,.flex_pp, .flex_pp_player, .flex_weight, .flex_rank {
            padding:0px;
            margin:0px;
        }

        .flex_star{
            font-size: """ + str(_star_font_size) + """px;
        }

        .flex_diff{
            font-size: """ + str(_diff_font_size) + """px;
        }

        .flex_acc{
            font-size: """ + str(_acc_font_size) + """px;
        }

        .flex_fc {
            font-size: """ + str(_fc_font_size) + """px;
        }

        .flex_pp{
            font-size: """ + str(_pp_font_size) + """px;
        }

        .flex_pp_player{
            font-size: """ + str(_pp_font_size-2) + """px;
        }

        .flex_rank, .flex_rank_player, .flex_modifier{
            padding:0px;
            margin:0px;
            text-align:right;
        }

        .flex_rank{
            font-size: """ + str(_rank_font_size) + """px;
        }

        .flex_rank_player {
            font-size: """ + str(_rank_font_size-2) + """px;
        }

        .flex_player{
            font-size: """ + str(_player_font_size) + """px;
        }

        .flex_weight{
            font-size: """ + str(_weight_font_size) + """px;
        }


        .flex_date {
            font-size: """ + str(_date_font_size) + """px;
            text-align:right;
        }

        .flex_modifier{
            color: #666;
            font-size: """ + str(_fc_font_size) + """px;
        }


        .flex_str_center{
            position: absolute;
            font-weight: bold;
            white-space:nowrap;
            overflow:hidden;
            color: #000;
            width:""" + str(_cover_image_size) + """px;
            text-shadow:1px 1px 0 #FFF, -1px -1px 0 #FFF,
                    -1px 1px 0 #FFF, 1px -1px 0 #FFF,
                    0px 1px 0 #FFF,  0-1px 0 #FFF,
                    -1px 0 0 #FFF, 1px 0 0 #FFF;
        }

        .flex_str_center {
            top:""" + str(_cover_image_size / 2 -10) + """px;     
            text-align:left;
            justify-content: center;
       }

        .flex_notesacc {
            display: flex;
            justify-content: space-between;
            align-items: center;
            flex-wrap: wrap;
         }

        .flex_acc_left, .flex_acc_right {
            display: flex;
            margin-right: 5px;
            margin-left: 5px;
            font-size: """ + str(_notes_acc_font_size) + """px;
            font-weight: 700;
        }

        .flex_acc_left {
            background:linear-gradient(transparent 92.5%, #EE6666 10%);
        }

        .flex_acc_right {
            background:linear-gradient(transparent 92.5%, #6666EE 10%);
        }

        h1 {
            padding: 3px 0 3px 3px;
            width: 100%;
            font-size: 150%;
            border-left: 4px solid #FFDE18;
        }

        </style>
        """


# ----------------------------------------
# Player html 
# ----------------------------------------
def func_player(_cover_image_size=200, _fc_is_enable=False):
    div_img = "<a href='https://scoresaber.com/u/{}' target='_blank'><img src='{}' style='width:{}px; height:{}px'/></a>".format(player_id, df_info["profilePicture"][0],_cover_image_size, _cover_image_size)
    div_name = "<div class='flex_player'>{}</div>".format(df_info["name"][0])

    div_playcount = "<div class='flex_song'>TotalPlayCount:{:,.0f}</div>".format(df_info["TotalPlay"][0])
    div_rankedplaycount = "<div class='flex_song'>RankedPlayCount:{:,.0f}</div>".format(df_info["RankedPlay"][0])
    div_playcount = "<div class='flex_song'>RankedPlay:{:,.0f}(Total:{:,.0f})</div>".format(df_info["RankedPlay"][0],df_info["TotalPlay"][0])
    div_fccount = "<div class='flex_song'>RankedFC:{:,.0f}(Total:{:,.0f})</div>".format(df_info["RankedFC"][0],df_info["TotalFC"][0]) if _fc_is_enable else ""
    span_acc = "<span class='flex_acc' style='{}'>{}</span>".format(color_acc_player(df_info["AveRankedAcc"][0]), format_acc(df_info["AveRankedAcc"][0]))
    div_acc = "<div>{}</div>".format(span_acc)

    span_pp = "<span class='flex_pp_player'>{}</span>".format((format_pp(df_info["pp"][0])))
    div_pp = "<div>{}</div>".format(span_pp)
    div_country_rank = "<div class='flex_rank_player'>#{:,.0f}[{}]</div>".format(df_info["countryRank"][0], df_info["country"][0])
    div_rank = "<div class='flex_rank_player'>#{:,.0f}</div>".format(df_info["rank"][0])
    return """
            <div class='flex_item'>{}<br/>
                <div class='flex_str_top'>
                    {}
                    {}
                    {}
                </div>
                <div class='flex_str_bottom_left'>
                    {}
                    {}
                </div>
                <div class='flex_str_bottom_right'>
                    {}
                    {}
                </div>
            </div>
            """.format(div_img, div_name, div_playcount,div_fccount,div_acc, div_pp, div_country_rank, div_rank)


flex_head = """
            <div id="imageDIV" 
                class='flex_box_wrapper'>
                <div class='flex_box'>
            """.format(tz_ja.strftime("%Y.%m.%d"), df_info["name"][0])

flex_player = func_player(200)

flex_end = "</div></div>"

img_css = func_tile_css()

html_str = flex_head + flex_player + flex_end + img_css

HTML(html_str)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: GitPython in /usr/local/lib/python3.9/dist-packages (3.1.31)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from GitPython) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from gitdb<5,>=4.0.1->GitPython) (5.0.0)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ------------------------------------
# timezone:Asia/Tokyo | datetime:2023-03-10 11:52:00.415389+09:00
#             <div id="imageDIV"
#                 class='flex_box_wrapper'>
#                 <div class='flex_box'>
#
#             <div class='flex_item'><a href='https://scoresaber.com/u/76561198412839195' target='_blank'><img src='https://cdn.scoresaber.com/avatars/76561198412839195.jpg' style='width:200px; height:200px'/></a><br/>
#                 <div class='flex_str_top'>
#                     <div class='flex_player'>hatopop</div>
#                     <div class='flex_song'>RankedPlay:3,211(Total:3,625)</div>
#
#                 </div>
#                 <div class='flex_str_bottom_left'>
#                     <div><span class='flex_acc' style='color: #ff4500; font-weight: bold;'>92.74%</span></div>
#                     <div><span class='flex_pp_player'>8664.9pp</span></div>
#                 </div>
#                 <div class='flex_str_bottom_right'>
#                     <div class='flex_rank_player'>#137[JP]</div>
#                     <div class='flex_rank_player'>#2,361</div>
#                 </div>
#             </div>
#             </div></div>
#         <style>
#         .flex_box {
#             width:1000px;
#             display: flex; /* フレックスボックスにする */;
#             flex-wrap: wrap;
#             padding:0px;
#             margin:0px;
#         }
#         .flex_item {
#             display: inline-block;
#             position: relative;
#             padding:0px 5px 0px 0px;
#             margin:0px;
#         }
#         .flex_str_top, .flex_str_bottom_left, .flex_str_bottom_right{
#             position: absolute;
#             font-weight: bold;
#             white-space:nowrap;
#             overflow:hidden;
#             color: #000;
#             width:190px;
#             text-shadow:1px 1px 0 #FFF, -1px -1px 0 #FFF,
#                     -1px 1px 0 #FFF, 1px -1px 0 #FFF,
#                     0px 1px 0 #FFF,  0-1px 0 #FFF,
#                     -1px 0 0 #FFF, 1px 0 0 #FFF;
#         }
#
#         .flex_str_top {
#             left: 5px;
#             top: 5px;
#         }
#
#         .flex_str_bottom_left {
#             left: 5px;
#             bottom: 5px;
#         }
#
#         .flex_str_bottom_right {
#             left: 5px;
#             bottom: 5px;
#         }
#
#         .flex_star, .flex_acc, .flex_accrank, .flex_fc ,.flex_pp, .flex_pp_player, .flex_weight, .flex_rank {
#             padding:0px;
#             margin:0px;
#         }
#
#         .flex_star{
#             font-size: 22px;
#         }
#
#         .flex_diff{
#             font-size: 18px;
#         }
#
#         .flex_acc{
#             font-size: 18px;
#         }
#
#         .flex_fc {
#             font-size: 18px;
#         }
#
#         .flex_pp{
#             font-size: 22px;
#         }
#
#         .flex_pp_player{
#             font-size: 20px;
#         }
#
#         .flex_rank, .flex_rank_player, .flex_modifier{
#             padding:0px;
#             margin:0px;
#             text-align:right;
#         }
#
#         .flex_rank{
#             font-size: 22px;
#         }
#
#         .flex_rank_player {
#             font-size: 20px;
#         }
#
#         .flex_player{
#             font-size: 22px;
#         }
#
#         .flex_weight{
#             font-size: 8px;
#         }
#
#
#         .flex_date {
#             font-size: 18px;
#             text-align:right;
#         }
#
#         .flex_modifier{
#             color: #666;
#             font-size: 18px;
#         }
#
#
#         .flex_str_center{
#             position: absolute;
#             font-weight: bold;
#             white-space:nowrap;
#             overflow:hidden;
#             color: #000;
#             width:200px;
#             text-shadow:1px 1px 0 #FFF, -1px -1px 0 #FFF,
#                     -1px 1px 0 #FFF, 1px -1px 0 #FFF,
#                     0px 1px 0 #FFF,  0-1px 0 #FFF,
#                     -1px 0 0 #FFF, 1px 0 0 #FFF;
#         }
#
#         .flex_str_center {
#             top:90.0px;
#             text-align:left;
#             justify-content: center;
#        }
#
#         .flex_notesacc {
#             display: flex;
#             justify-content: space-between;
#             align-items: center;
#             flex-wrap: wrap;
#          }
#
#         .flex_acc_left, .flex_acc_right {
#             display: flex;
#             margin-right: 5px;
#             margin-left: 5px;
#             font-size: 24px;
#             font-weight: 700;
#         }
#
#         .flex_acc_left {
#             background:linear-gradient(transparent 92.5%, #EE6666 10%);
#         }
#
#         .flex_acc_right {
#             background:linear-gradient(transparent 92.5%, #6666EE 10%);
#         }
#
#         h1 {
#             padding: 3px 0 3px 3px;
#             width: 100%;
#             font-size: 150%;
#             border-left: 4px solid #FFDE18;
#         }
#
#         </style>

# %% [markdown]
# # Data Collection

# %%
#@title Get Ranked Song Data
#@markdown ScoreSaber's Ranked Song Data from [RankedMapData](https://github.com/rakkyo150/RankedMapData) by [rakkyo150](https://twitter.com/rakkyo150)

headers = {
    'Accept': 'application/vnd.github.v3+json',
}

response = requests.get(rankedmapdata_url, headers=headers)

data = response.json()

# 最新releaseのcsvのurl取得
url_rankmap_data = data[0]["assets"][0]["browser_download_url"]

file_name = os.path.join(data_path, os.path.basename(url_rankmap_data))
result = requests.get(url_rankmap_data, stream=True)
if result.status_code == 200:
    with open(file_name, 'wb') as file:
        result.raw.decode_content = True
        shutil.copyfileobj(result.raw, file)

df_rankmap_data = pd.read_csv(file_name)
df_rankmap_data = df_rankmap_data[[x for x in df_rankmap_data.columns if not x.startswith("Unnamed")]]
df_rankmap_data["hash"] = df_rankmap_data["hash"].str.upper()
df_rankmap_data["Preview"] = '<audio src="' + df_rankmap_data["previewUrl"] + '" preload="none" controls></audio>'

df_rankmap_data = df_rankmap_data.rename(columns=lambda x: x.capitalize())

df_rankmap_data.rename(columns={
                        "Songname":"SongName",
                        "Songsubname":"SongSub",
                        "Songauthorname":"SongAuthor",
                        "Levelauthorname":"LevelAuthor"
                            }, inplace=True)

# 準備
df_rankmap_data["Song"] = df_rankmap_data["SongName"] + " / " + df_rankmap_data["SongAuthor"] + " [" + df_rankmap_data["LevelAuthor"] + "]"
df_rankmap_data["Level"] = df_rankmap_data["Stars"].astype("int")
df_rankmap_data["LevelStr"] = df_rankmap_data["Level"].astype("str")

print("path:{},count:{:,}".format(file_name,len(df_rankmap_data["Hash"])))
# Out:
# path:/content/drive/MyDrive/MyBeatSaberAnalysis/data/outcome.csv,count:3,778

# %%
#@title Get Player Scores Data
#@markdown Players' Score Data from ScoreSaber Public API - [doc](https://docs.scoresaber.com/)  

def func_mode(x):
    if  x == "SoloStandard":
        return "Standard"
    else:
        return x

def func_score(x):
    if  x > 100:
        return "-"
    elif x == 100:
        return "SSS"
    elif x >= ss_plus_val and ss_plus_is_enable:
        return ss_plus
    elif x >= 90:
        return "SS"
    elif x >= 80:
        return "S"
    elif x >= 65:
        return "A"
    elif x >= 50:
        return "B"
    elif x >= 35:
        return "C"
    elif x >= 20:
        return "D"
    elif x >= 0:
        return "E"
    else:
        return "-"

def func_fc(x):
    if  x:
        return "FC"
    else:
        return "-"

def func_Recent(x):
    if  x <= Recent:
        return 1
    else:
        return 0

if saved_player_score_is_enable and os.path.exists(player_score_pickle_path):    
    df_scores_pkl = pd.read_pickle(player_score_pickle_path)
    _df_scores_pkl = df_scores_pkl.head(0)

    i = 1
    while True:
        url = r"https://scoresaber.com/api/player/{}/scores?sort=recent&page={}&limit={}".format(player_id, i, page_count)
        try:
            response = requests.get(url)
            res_data = response.json()
            _df_scores_pkl=_df_scores_pkl.append(json_normalize(res_data['playerScores']), ignore_index=True)
            if df_scores_pkl['score.timeSet'].max() > _df_scores_pkl['score.timeSet'].min():
                break
        except:
            break

    df_scores=df_scores_pkl.append(_df_scores_pkl, ignore_index=True).sort_values("score.timeSet", ascending=False).groupby("score.id").head(1)

else:
    url = r"https://scoresaber.com/api/player/{}/scores?sort=recent&limit={}".format(player_id, page_count)
    response = requests.get(url)
    res_data = response.json()
    df_scores = json_normalize(res_data['playerScores'])

    for i in tqdm(range(2, RangeCount)):
        url = r"https://scoresaber.com/api/player/{}/scores?sort=recent&page={}&limit={}".format(player_id, i, page_count)
        try:
            response = requests.get(url)
            res_data = response.json()
            df_scores=df_scores.append(json_normalize(res_data['playerScores']), ignore_index=True)
        except:
            break

# 未加工データ保存
df_scores.to_pickle(player_score_pickle_path)

# 加工
df_scores['Song'] = df_scores['leaderboard.songName'] + " " + df_scores['leaderboard.songSubName'] + " / " + df_scores['leaderboard.songAuthorName'] + " [" + df_scores['leaderboard.levelAuthorName'] + "]"
df_scores['SongName'] = df_scores['leaderboard.songName']
df_scores['SongSub'] = df_scores['leaderboard.songSubName']
df_scores['SongAuthor'] = df_scores['leaderboard.songAuthorName']
df_scores['LevelAuthor'] = df_scores['leaderboard.levelAuthorName']
df_scores['Hash'] = df_scores['leaderboard.songHash'].str.upper()

def func_higher_score(x):
    try:
        if x[0] >= x[1]:
            return x[0]
        else:
            return x[1]
    except:
        return x[1]

if score_mode == "BaseScore":
    df_scores['Score'] = df_scores['score.baseScore']
elif score_mode == "ModifiedScore":
    df_scores['Score'] = df_scores['score.modifiedScore']
elif score_mode == "HigherScore":
    df_scores['Score'] = df_scores[['score.baseScore','score.modifiedScore']].apply(func_higher_score, axis=1)
else:
    df_scores['Score'] = df_scores['score.modifiedScore']

df_scores['Acc'] = df_scores['Score'] / df_scores['leaderboard.maxScore'] * 100
# df_scores['Acc'] = df_scores['score.modifiedScore'] / df_scores['leaderboard.maxScore'] * 100
df_scores['MaxScore'] = df_scores['leaderboard.maxScore']

df_scores['Mode'] = df_scores['leaderboard.difficulty.gameMode'].apply(func_mode)
#df_scores['Mode'] = df_scores['leaderboard.difficulty.gameMode']
_df_scores = df_scores['leaderboard.difficulty.difficultyRaw'].str.split('_', expand=True)
_df_scores.columns = ['_','Difficulty', 'Mode']
df_scores['Difficulty'] = _df_scores['Difficulty']
df_scores['Stars'] = df_scores['leaderboard.stars']
df_scores['Level'] = df_scores['Stars'].astype('int')
df_scores["LevelStr"] = df_scores['Level'].astype('str')
# df_scores['Score'] = df_scores['score.modifiedScore']
df_scores['Bad'] = df_scores['score.badCuts']
# df_scores['Miss'] = df_scores['score.missedNotes']
# Bad cutを上乗せ
df_scores['Miss'] = df_scores['score.missedNotes'] + df_scores['Bad']
df_scores['Combo'] = df_scores['score.maxCombo']
df_scores['PP'] = df_scores['score.pp']
df_scores['PPWeight'] = df_scores['score.pp'] * df_scores['score.weight']
df_scores['Rank'] = df_scores['score.rank']
df_scores['Modifiers'] = df_scores['score.modifiers']
df_scores['Ranked'] = df_scores['leaderboard.ranked']
df_scores['Qualified'] = df_scores['leaderboard.qualified']
df_scores['Play'] = df_scores['leaderboard.plays']
df_scores['DailyPlay'] = df_scores['leaderboard.dailyPlays']
df_scores['DateUtc'] = pd.to_datetime(df_scores['score.timeSet'])
_df_scores_idx = df_scores.set_index('DateUtc')
df_scores['DateJa'] = _df_scores_idx.index.tz_convert(timezone)
df_scores['Date'] = df_scores['DateJa'].dt.date
df_scores['Days'] = (tz_ja.date() - df_scores['Date']).dt.days
df_scores = df_scores.set_index('DateJa')
df_scores['Months'] = (df_scores['Days'] / 30).astype('int')
df_scores['DaysStr'] = df_scores['Days'].astype('str')
df_scores['MonthsStr'] = df_scores['Months'].astype('str')

df_scores['Recent'] = df_scores['Days'].apply(func_Recent)
df_scores['RecentStr'] = df_scores['Recent'].astype('str')

df_scores['AccRank'] = df_scores['Acc'].apply(func_score)

df_scores['Cover'] = '<img src="'+df_scores['leaderboard.coverImage']+'" style="width:{}px;"/>'.format(cover_image_size)

df_scores['FC'] = df_scores['score.fullCombo'].apply(func_fc)

df_scores = df_scores[[x for x in df_scores.columns if not x.startswith("score.")]]
df_scores = df_scores[[x for x in df_scores.columns if not x.startswith("leaderboard.")]]


# 結合前Score情報の抽出(LevelClearedProgress用)
df_scores_org = df_scores.copy()

# 改行コード等の除去
for col in df_scores.columns:
    try:
        if len(df_scores[df_scores[col].str.contains("\n")][[col]]) == 0:
            continue
        else:
            df_scores[col] = df_scores[col].str.replace("\n","")
    except:
        continue

for col in df_scores.columns:
    try:
        if len(df_scores[df_scores[col].str.contains("\r")][[col]]) == 0:
            continue
        else:
            df_scores[col] = df_scores[col].str.replace("\r","")
    except:
        continue


# RankedMap(らっきょさんのBeatSaverデータ)の情報結合
df_scores = df_scores.reset_index()
#df_scores = pd.merge(df_scores, df_rankmap_data[cols_rankedmap], on=["Hash", "Difficulty"], how="left", suffixes=("", "_y"))
df_scores = pd.merge(df_scores, df_rankmap_data, on=["Hash", "Difficulty"], how="left", suffixes=("", "_y"))
df_scores = df_scores[[x for x in df_scores.columns if not x.endswith("_y")]]
df_scores = df_scores.set_index("DateJa")
# df_scores = df_scores.drop('index', axis=1).drop_duplicates()

#Score情報の保存
df_scores[(df_scores['Ranked'] == True)][cols_score].sort_index(ascending=False).to_csv(player_ranked_path)
df_scores = df_scores[(df_scores['Ranked'] == True)].sort_index(ascending=False)
df_scores.sort_index(ascending=False).to_csv(player_score_path.format(player_id))

print('ScoreCount:{}, RecentPlayCount:{}, RankedPlayCount:{}'.format(df_scores['Play'].count(), df_scores[(df_scores['Recent'] == 1)]['Play'].count(), df_scores[
                                    (df_scores['Ranked']==1)
                                    & (df_scores['Mode']=="Standard")]['Play'].count()))

# ---------------------------------------
#@title Acc再計算 
# ---------------------------------------
#@markdown ---
#@markdown <h4>Visible</h4>
recalq_visible = False #@param {type:"boolean"}

def func_max_score(x):
    combo_a = 115 * 1
    combo_b = 115 * 2
    combo_c = 115 * 4
    combo_d = 115 * 8

    if  x >= 14:
        return combo_d * (x - 13) + combo_a + combo_b * 4 + combo_c * 8
    elif x >= 6:
        return combo_c * (x - 5) + combo_a + combo_b * 4
    elif x >= 2:
        return combo_b * (x - 1) + combo_a
    elif x >= 1:
        return combo_a
    else:
        return 0

df_scores['MaxScore'] = df_scores['MaxScore']
df_scores['MaxScoreRecalq'] = df_scores['Notes'].apply(func_max_score)
df_scores['AccRecalq'] = df_scores['Score'] / df_scores['MaxScoreRecalq'] * 100
df_scores['AccRankRecalq'] = df_scores['AccRecalq'].apply(func_score)
df_scores['MaxScoreDiff'] = df_scores['MaxScore'].fillna(0) - df_scores['MaxScoreRecalq'].fillna(0)
df_scores['AccDiff'] = df_scores['Acc'].fillna(0) - df_scores['AccRecalq'].fillna(0)

df_errors = df_scores[
            (1==1)
            &(df_scores['Ranked'])
            &(df_scores['MaxScoreDiff'] != 0)
            ]

print('There are {} results where Acc is different from the game.'.format(len(df_errors)))
#print('Accがゲームと異なる結果が{}件あります。'.format(len(df_errors)))

if acc_recalq_override_is_enable:
    df_scores.rename(columns={
                            "MaxScore":"MaxScoreOrg",
                             "Acc":"AccOrg",
                             "AccRank":"AccRankOrg"
                             }, inplace=True)
    df_scores.rename(columns={
                            "MaxScoreRecalq":"MaxScore",
                             "AccRecalq":"Acc",
                             "AccRankRecalq":"AccRank"
                             }, inplace=True)
    print('Use the result of recalculating Acc.')

if recalq_visible:
    print('The following are the results extracted during recalculation.')
else:
    df_errors = df_errors.head(0)
    #print('表示設定は無効です。')

df_errors[cols_recalq].style.set_table_styles(styles_data).applymap(
    color_negative_red, subset=["AccDiff","MaxScoreDiff"]
        ).applymap(
            color_difficulty, subset=["Difficulty"]
        ).applymap(
            color_acc_rank, subset=["AccRank","AccRankRecalq"]
        # ).applymap(
        #     color_fc, subset=["FC"]
        ).format(
            style_format, na_rep="-"
        )
# Out:
# ScoreCount:3211, RecentPlayCount:12, RankedPlayCount:3211
# There are 3 results where Acc is different from the game.
# Use the result of recalculating Acc.
# <style type="text/css">
# #T_c72cc_ td {
#   padding-top: 0px;
#   padding-bottom: 0px;
# }
# #T_c72cc_ th {
#   padding-top: 0px;
#   padding-bottom: 0px;
# }
# </style>
# <table id="T_c72cc_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Hash</th>
#       <th class="col_heading level0 col1" >Cover</th>
#       <th class="col_heading level0 col2" >SongName</th>
#       <th class="col_heading level0 col3" >Difficulty</th>
#       <th class="col_heading level0 col4" >Stars</th>
#       <th class="col_heading level0 col5" >Notes</th>
#       <th class="col_heading level0 col6" >Acc</th>
#       <th class="col_heading level0 col7" >AccRecalq</th>
#       <th class="col_heading level0 col8" >AccDiff</th>
#       <th class="col_heading level0 col9" >AccRank</th>
#       <th class="col_heading level0 col10" >AccRankRecalq</th>
#       <th class="col_heading level0 col11" >MaxScore</th>
#       <th class="col_heading level0 col12" >MaxScoreRecalq</th>
#       <th class="col_heading level0 col13" >MaxScoreDiff</th>
#       <th class="col_heading level0 col14" >Score</th>
#       <th class="col_heading level0 col15" >Miss</th>
#       <th class="col_heading level0 col16" >Combo</th>
#       <th class="col_heading level0 col17" >Preview</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >DateJa</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# # Acc Prediction Model

# %%
#@title My Stats & Range
top_n = 100 #@param {type:"slider", min:10, max:100, step:10}
# -----------------------------
# Stats
# -----------------------------

from math import ceil
cols_temp = ["Stars","PP","Acc","Nps","Njs","Duration","Notes","Miss"]
df_scores_top_pp = df_scores[cols_temp].sort_values("PP", ascending=False).head(top_n).reset_index(drop=True)# .describe()

star_mean = df_scores_top_pp["Stars"].mean()
star_std =df_scores_top_pp["Stars"].std()
nps_mean = df_scores_top_pp["Nps"].mean()
nps_std =df_scores_top_pp["Nps"].std()
njs_mean = df_scores_top_pp["Njs"].mean()
njs_std =df_scores_top_pp["Njs"].std()

df_scores_top_pp.reset_index(drop=True)
df_stats = df_scores_top_pp.describe()#.drop('count', inplace=True)
df_stats.drop('count', inplace=True)
    
caption_msg = "My Top {} PPs Stats - {} - {}".format(top_n, tz_ja.strftime("%Y.%m.%d"), df_info["name"][0])

display(df_stats.style.set_table_styles(styles_data
                                        # ).background_gradient(subset=['+PP'], cmap='coolwarm'
                                        ).format(style_format
                                        ).set_caption(caption_msg #"Playlist Simulation (now:{:,.2f}pp->target:{:,.2f}pp) - method:{} - {} - {}".format(now_pp, target_total_pp, pp_eat_target, tz_ja.strftime("%Y.%m.%d"), df_info["name"][0])
                                        ).set_table_styles(caption_styles)
)

print("\n")

import pandas as pd

star_start = ceil((star_mean - star_std)*10)/10
star_end = round(star_mean + star_std, 1)

# DataFrameを作成
stats2 = {
        'star_start': [ceil((star_mean - star_std)*10)/10],
        'star_end': [round(star_mean + star_std, 1)],
        'nps_start': [ceil((nps_mean - nps_std)*10)/10],
        'nps_end': [round(nps_mean + nps_std, 1)],
        'njs_start': [ceil((njs_mean - njs_std))],
        'njs_end': [round(njs_mean + njs_std, 0)],
        'Player': [df_info["name"][0]],        
         }

df_stats2 = pd.DataFrame(stats2)

def func_stats_2(x):
    star_start = x[0]
    star_end = x[1]
    nps_start = x[2]
    nps_end = x[3]
    njs_start = x[4]
    njs_end = x[5]
    return "{:,.1f}-{:,.1f}★".format(star_start, star_end),"{:,.1f}-{:,.1f}".format(nps_start, nps_end),"{:,.0f}-{:,.0f}".format(njs_start, njs_end)


df_stats2[['Stars', 'Nps', 'Njs']] = df_stats2.apply(func_stats_2, axis=1, result_type='expand')

caption_msg = "My Eat Range"

display(df_stats2[['Stars', 'Nps', 'Njs','Player']].style.set_table_styles(styles_data
                                        ).set_caption(caption_msg
                                        ).set_table_styles(caption_styles)
)
# Out:
# <style type="text/css">
# #T_22be0_ caption {
#   text-align: lett;
#   font-size: 150%;
#   border-bottom: 1px solid;
# }
# </style>
# <table id="T_22be0_" class="dataframe">
#   <caption>My Top 100 PPs Stats - 2023.03.10 - hatopop</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Stars</th>
#       <th class="col_heading level0 col1" >PP</th>
#       <th class="col_heading level0 col2" >Acc</th>
#       <th class="col_heading level0 col3" >Nps</th>
#       <th class="col_heading level0 col4" >Njs</th>
#       <th class="col_heading level0 col5" >Duration</th>
#       <th class="col_heading level0 col6" >Notes</th>
#       <th class="col_heading level0 col7" >Miss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22be0_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_22be0_row0_col0" class="data row0 col0" >7.66★</td>
#       <td id="T_22be0_row0_col1" class="data row0 col1" >291.70pp</td>
#       <td id="T_22be0_row0_col2" class="data row0 col2" >93.35%</td>
#       <td id="T_22be0_row0_col3" class="data row0 col3" >7.07</td>
#       <td id="T_22be0_row0_col4" class="data row0 col4" >19</td>
#       <td id="T_22be0_row0_col5" class="data row0 col5" >215</td>
#       <td id="T_22be0_row0_col6" class="data row0 col6" >1,439</td>
#       <td id="T_22be0_row0_col7" class="data row0 col7" >3</td>
#     </tr>
#     <tr>
#       <th id="T_22be0_level0_row1" class="row_heading level0 row1" >std</th>
#       <td id="T_22be0_row1_col0" class="data row1 col0" >0.57★</td>
#       <td id="T_22be0_row1_col1" class="data row1 col1" >13.62pp</td>
#       <td id="T_22be0_row1_col2" class="data row1 col2" >1.20%</td>
#       <td id="T_22be0_row1_col3" class="data row1 col3" >1.30</td>
#       <td id="T_22be0_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_22be0_row1_col5" class="data row1 col5" >68</td>
#       <td id="T_22be0_row1_col6" class="data row1 col6" >516</td>
#       <td id="T_22be0_row1_col7" class="data row1 col7" >4</td>
#     </tr>
#     <tr>
#       <th id="T_22be0_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_22be0_row2_col0" class="data row2 col0" >6.23★</td>
#       <td id="T_22be0_row2_col1" class="data row2 col1" >275.53pp</td>
#       <td id="T_22be0_row2_col2" class="data row2 col2" >89.90%</td>
#       <td id="T_22be0_row2_col3" class="data row2 col3" >4.43</td>
#       <td id="T_22be0_row2_col4" class="data row2 col4" >16</td>
#       <td id="T_22be0_row2_col5" class="data row2 col5" >59</td>
#       <td id="T_22be0_row2_col6" class="data row2 col6" >453</td>
#       <td id="T_22be0_row2_col7" class="data row2 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_22be0_level0_row3" class="row_heading level0 row3" >25%</th>
#       <td id="T_22be0_row3_col0" class="data row3 col0" >7.23★</td>
#       <td id="T_22be0_row3_col1" class="data row3 col1" >279.49pp</td>
#       <td id="T_22be0_row3_col2" class="data row3 col2" >92.51%</td>
#       <td id="T_22be0_row3_col3" class="data row3 col3" >6.19</td>
#       <td id="T_22be0_row3_col4" class="data row3 col4" >18</td>
#       <td id="T_22be0_row3_col5" class="data row3 col5" >156</td>
#       <td id="T_22be0_row3_col6" class="data row3 col6" >1,092</td>
#       <td id="T_22be0_row3_col7" class="data row3 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_22be0_level0_row4" class="row_heading level0 row4" >50%</th>
#       <td id="T_22be0_row4_col0" class="data row4 col0" >7.62★</td>
#       <td id="T_22be0_row4_col1" class="data row4 col1" >289.44pp</td>
#       <td id="T_22be0_row4_col2" class="data row4 col2" >93.64%</td>
#       <td id="T_22be0_row4_col3" class="data row4 col3" >6.96</td>
#       <td id="T_22be0_row4_col4" class="data row4 col4" >19</td>
#       <td id="T_22be0_row4_col5" class="data row4 col5" >224</td>
#       <td id="T_22be0_row4_col6" class="data row4 col6" >1,312</td>
#       <td id="T_22be0_row4_col7" class="data row4 col7" >2</td>
#     </tr>
#     <tr>
#       <th id="T_22be0_level0_row5" class="row_heading level0 row5" >75%</th>
#       <td id="T_22be0_row5_col0" class="data row5 col0" >8.02★</td>
#       <td id="T_22be0_row5_col1" class="data row5 col1" >299.05pp</td>
#       <td id="T_22be0_row5_col2" class="data row5 col2" >94.19%</td>
#       <td id="T_22be0_row5_col3" class="data row5 col3" >8.01</td>
#       <td id="T_22be0_row5_col4" class="data row5 col4" >20</td>
#       <td id="T_22be0_row5_col5" class="data row5 col5" >258</td>
#       <td id="T_22be0_row5_col6" class="data row5 col6" >1,754</td>
#       <td id="T_22be0_row5_col7" class="data row5 col7" >5</td>
#     </tr>
#     <tr>
#       <th id="T_22be0_level0_row6" class="row_heading level0 row6" >max</th>
#       <td id="T_22be0_row6_col0" class="data row6 col0" >8.93★</td>
#       <td id="T_22be0_row6_col1" class="data row6 col1" >336.08pp</td>
#       <td id="T_22be0_row6_col2" class="data row6 col2" >95.57%</td>
#       <td id="T_22be0_row6_col3" class="data row6 col3" >10.11</td>
#       <td id="T_22be0_row6_col4" class="data row6 col4" >23</td>
#       <td id="T_22be0_row6_col5" class="data row6 col5" >404</td>
#       <td id="T_22be0_row6_col6" class="data row6 col6" >2,665</td>
#       <td id="T_22be0_row6_col7" class="data row6 col7" >24</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c5fcc_ caption {
#   text-align: lett;
#   font-size: 150%;
#   border-bottom: 1px solid;
# }
# </style>
# <table id="T_c5fcc_" class="dataframe">
#   <caption>My Eat Range</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Stars</th>
#       <th class="col_heading level0 col1" >Nps</th>
#       <th class="col_heading level0 col2" >Njs</th>
#       <th class="col_heading level0 col3" >Player</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5fcc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5fcc_row0_col0" class="data row0 col0" >7.1-8.2★</td>
#       <td id="T_c5fcc_row0_col1" class="data row0 col1" >5.8-8.4</td>
#       <td id="T_c5fcc_row0_col2" class="data row0 col2" >18-21</td>
#       <td id="T_c5fcc_row0_col3" class="data row0 col3" >hatopop</td>
#     </tr>
#   </tbody>
# </table>

# %%
#@title ## Build My Acc Prediction Model
#@markdown ---
#@markdown <h4>Predict Parameters</h4>

#@markdown <b>features include</b>
pred_days_dependent_is_enable = True #@param {type:"boolean"}
pred_miss_dependent_is_enable = True #@param {type:"boolean"}
#@markdown <b>outlier removal</b>
modifiers_removal_keyword = "NF" #@param {type:"string"}
removal_knn_is_enable = False #@param {type:"boolean"}
knn_param = 20 #@param {type:"slider", min:3, max:90, step:1}

# -----------------------------
# get target_players score
# -----------------------------

df_result = df_rankmap_data.copy()

# ---------------------------
# Star Acc → PP算出用関数
# ---------------------------
_curve_y_acc = [curve[i][0] for i in range(len(curve))]
fleg = interpolate.interp1d(_curve_y_acc, curve_c)

def func_star_acc_to_pp(x):
    star = x[0]
    target_acc = x[1]
    if target_acc > 100:
        target_acc = 100
    k = fleg(target_acc/100)
    return star * c * k

df_scores_set = df_scores.copy()
df_target_result = df_result.copy()

if len(modifiers_removal_keyword) > 0:
    df_scores_set = df_scores_set[~df_scores_set["Modifiers"].str.contains(modifiers_removal_keyword)]

# ---------------------------
# Acc, PPの予測処理
# ---------------------------
# 過去のプレイデータからAccを予測しPPを算出
cols_pred = ['Stars','Njs','Notes', 'Bombs', 'Obstacles', 'Nps','Length','Seconds', 'Errors', 'Warns', 'Resets']

if pred_days_dependent_is_enable:
    cols_pred.append('Days')

if pred_miss_dependent_is_enable:
    cols_pred.append('Miss')

# データセットから異常値除去
if removal_knn_is_enable:
    from sklearn.neighbors import LocalOutlierFactor
    import pandas as pd

    # # 特徴量の列を取り出す
    kX = df_scores_set[['Stars', 'Acc']].dropna()

    # k-近傍法のパラメータを設定する
    k = knn_param

    # モデルを定義する
    k_model = LocalOutlierFactor(n_neighbors=k, contamination=0.1)

    # モデルによる異常値検出を実行する
    y_k_pred = k_model.fit_predict(kX)

    # 異常値を除いたデータを取り出す
    df_scores_set = df_scores_set[y_k_pred == 1].dropna()


# データセットからプレイリストで抽出した譜面セット除去
df_scores_set = pd.merge(df_scores_set, df_result[['Hash', 'Stars']], on=['Hash', 'Stars'], how='left', suffixes=('', '_drop'))
df_scores_set = df_scores_set.loc[:, ~df_scores_set.columns.str.endswith('_drop')]

# x = df_scores_set[['Stars','Njs','Notes', 'Bombs', 'Obstacles', 'Nps','Length','Seconds', 'Errors', 'Warns', 'Resets']]
x = df_scores_set[cols_pred].dropna()
y = df_scores_set['Acc'].dropna()

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

model = xgb.XGBRegressor()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
y_pred_train = model.predict(x_train)

#決定係数R2:1に近いほどよい
result_r2 = r2_score(y_test, y_pred)
# 二乗誤差:低いほどよい
result_mse = mean_squared_error(y_test, y_pred)

if result_r2 > 0.95:
    result_eval_msg = """
    [Excellent]
    The prediction model fits the data extremely well.
    Acc予測モデルはデータに非常に適合しており、非常に高い予測精度がある
    """
elif result_r2 > 0.9:
    result_eval_msg = """
    [Marvelous]
    The prediction model fits the data highly well.
    Acc予測モデルはデータに非常に適合しており、高い予測精度がある
    """
elif result_r2 > 0.8:
    result_eval_msg = """
    [Great]
    The prediction model fits the data well and has some explanatory power.
    Acc予測モデルはデータによく適合しており、ある程度説明力がある
    """
elif result_r2 > 0.7:
    result_eval_msg = """
    [Cooｌ]
    The prediction model fits the data to some extent, but its explanatory power is relatively low.
    Acc予測モデルはデータにある程度適合しているが、比較的説明力が低いため注意
    """
elif result_r2 > 0.6:
    result_eval_msg = """
    [Good]
    The prediction model fits the data to some extent, but has low explanatory power.
    Acc予測モデルはデータにある程度適合しているが、説明力が低いため注意
    """
elif result_r2 > 0.5:
    result_eval_msg = """
    [So-so]
    Acc予測モデルはデータにある程度適合しているが、予測精度が低いため使用を推奨しない
    """
elif result_r2 > 0.3:
    result_eval_msg = """
    [Bad]
    The prediction model does not fit the data well and has low predictive accuracy.
    Acc予測モデルはデータにあまり適合しておらず、予測精度が低いため使用するべきではない
    """
else:
    result_eval_msg = """
    [Miss]
    The prediction model has no fit to the data and has extremely low predictive accuracy.
    Acc予測モデルはデータに全く適合しておらず、予測精度が非常に低いため使用するべきではない
    """


print("-----prediction summary-----")
print("N: {:.0f} -> N(Removed): {:.0f}".format(len(df_scores[['Stars', 'Acc']].dropna().drop_duplicates()),len(x)))
print("Train: {:.0f}, Test: {:.0f}".format(len(x_train),len(x_test)))
print("R2 score: {:.2f}, MSE: {:.2f}".format(result_r2, result_mse))
print(result_eval_msg)
print("-----prediction summary-----")
print("")

fig = px.scatter(x=y_test, y=y_pred,#color=color,
                 width=400, height=400)

# Traceに名前を付ける
fig.data[0].name = "test"

fig.add_scatter(x=y_test, y=y_pred, mode='markers', name="test")

fig.add_scatter(x=y_train, y=y_pred_train, mode='markers', name="train")

fig.update_layout(title="Acc Pred Eval - {} - {}".format(tz_ja.strftime("%Y.%m.%d"), df_info["name"][0]), title_x=0.5,
            xaxis_title = "Acc", yaxis_title="Acc_pred"
            )

# plotly ファイル名設定
plot_name = "ModelEval"
config = {
    'toImageButtonOptions': {
        'format': 'png', 
        'filename': "{}_{}_{}".format(plot_name, df_info["name"][0], tz_ja.strftime("%Y%m%d_%H%M%S")),
        'scale': 1 # Multiply title/legend/axis/canvas sizes by this factor
    }
}

fig.show(config=config)
# Out:
# -----prediction summary-----
# N: 3211 -> N(Removed): 3161
# Train: 2528, Test: 633
# R2 score: 0.96, MSE: 0.70
#
#     [Excellent]
#     The prediction model fits the data extremely well.
#     Acc予測モデルはデータに非常に適合しており、非常に高い予測精度がある
#
# -----prediction summary-----
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="27852a51-77cf-466f-ac21-88df83fba3f7" class="plotly-graph-div" style="height:400px; width:400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27852a51-77cf-466f-ac21-88df83fba3f7")) {                    Plotly.newPlot(                        "27852a51-77cf-466f-ac21-88df83fba3f7",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"test","orientation":"v","showlegend":false,"x":[94.34763564341351,85.489507566257,95.1633510842496,94.31805865890685,93.56662733828446,90.89209175400204,95.65766800689259,95.071603169778,93.93760962763645,96.68154777247373,93.2750849455655,92.05803270766178,93.8236610151217,96.69517976750856,91.42526765776758,95.3377773355885,95.02613305673208,97.43592836036905,91.53958666474676,96.63127305241981,95.25641268100182,96.31484352490843,97.43344543944245,96.03675286539737,95.78195976638546,96.04875386574496,97.14410353351752,91.89944756658653,96.23947324165944,95.13301445692481,92.14131512237932,94.57651103511462,96.08939528440851,95.24798058876596,96.99184381221502,95.56776692780852,88.77079400177081,95.21902019168746,95.8821293128228,91.86902999214742,95.3543573151144,93.89667798218177,96.07505119291395,90.17620588223295,97.2846941059185,92.71425966984044,94.84599912100322,91.89365713183012,97.97816198436573,95.17422097172495,95.68464982168602,90.65287458932585,91.5259734409629,86.31340486068349,97.7191732002851,93.95234759772782,95.03757232372219,95.3695186372372,95.81985199533891,95.01133749453739,91.36342369460932,94.65236501550869,95.69093252478048,95.77570753183545,91.64512693758957,97.9375630447715,94.51397329726305,95.527950310559,95.10982250539061,97.49941245593419,96.23060264739425,95.21322653442715,93.6654290572192,96.33076993272111,93.58157045272392,96.10940375148122,95.54279692581625,97.04029578321712,97.27054671776351,85.05820206993809,94.80684813400664,92.43149687635646,91.87542576038855,96.42077944301055,96.46034182432783,96.17400175199316,95.80705306383904,95.49155697380668,92.20795477385656,95.03647564596906,91.54184267304841,95.24267069306704,84.46511870552075,97.30548133754353,95.98832402386432,94.2245688265818,94.33705876952098,94.90186527366026,96.61957678603301,95.9027748147516,97.29459791526297,94.85020866013556,96.48614648215765,90.97469022221651,97.33050184419358,94.7960392171227,94.95408168958552,92.61418522411496,93.80330410926224,97.5347377857463,87.38446850356112,96.41634898422043,91.29416994718031,94.88474077493436,95.7492377996087,91.61306165665792,93.42179651578806,96.51168106798336,96.45943150522761,95.66858080393766,96.52827721477607,83.85294979036904,91.80217469008853,95.13084612928193,89.57269921945907,96.60176046945853,96.44639141386484,95.21014781568961,92.3307690091336,97.35222758990875,95.46707075416715,94.60615756397534,94.1998799583013,89.31389601521865,93.87546131704772,94.5478123087771,96.59637459557683,96.48123450204005,82.09655099700831,94.26753887427566,97.86030384597838,92.63638182393143,92.40206512918819,87.31014953206478,89.43573763336909,91.1802291986065,97.67654522955598,83.17828374816897,93.07484059943488,93.94814867525321,95.83105928315624,96.96298996836448,90.72198999072471,96.1439063665999,96.68619696850878,95.24241175662684,94.53280858231837,96.83207087702982,92.45369819054721,90.81825083069572,94.33420326448734,98.02898550724638,94.66133196735497,93.71393067175285,90.28718170872824,90.54314588953818,94.61526387597648,94.50173083331633,93.70751286618348,97.3698162059339,95.6041929621971,94.23855048044638,93.98251493050192,94.94174867096483,92.04070803584825,94.52552779795128,96.52010276382322,80.72515589642603,87.28866927356658,94.41016453913836,94.15146662013697,96.27280178411452,84.46376145298996, ...

# %% [markdown]
# # Simulations

# %% [markdown]
# ## S1: PP Simulation

# %%
#@title PP Simulation

#@markdown ※以降のシミュレーションでここでの設定は引き継がれます。
start_pp = 280 #@param {type:"integer"}
end_pp = 350 #@param {type:"integer"}
step = 10 #@param {type:"integer"}
# eat_pp = 320 #@param {type:"integer"}
target_total_pp = 9000 #@param {type:"integer"}
target_plus_pp = 100 #param {type:"integer"}
limit_eat_count = 100 #@param {type:"integer"}
# start_star = 7 #@param {type:"integer"}
# end_star = 8 #@param {type:"integer"}
my_star_range_is_auto = True #@param {type:"boolean"}

start_star = 7 #@param {type:"slider", min:0, max:15, step:0.1}
end_star = 8.5 #@param {type:"slider", min:0, max:15, step:0.1}
step_star = 0.5 #@param {type:"slider", min:0.1, max:2, step:0.1}


if my_star_range_is_auto:
    start_star = df_stats2['star_start'][0]
    end_star = df_stats2['star_end'][0]
    print('my star range is auto.:{}-{}\n'.format(start_star,end_star))

now_pp = df_info['pp'][0]
target_pp_is_active = True

# total_ppがtarget_total_ppより低い場合の再設定 
if target_total_pp <= now_pp:
    print("[caution!!!]")
    print("target_total_pp was lower than the current total_pp.")
    print("target modified: {:,.1f}pp->{:,.1f}pp({:+,.0f}pp). \n\n".format(target_total_pp, now_pp + target_plus_pp,target_plus_pp))
    target_total_pp = now_pp + target_plus_pp
    target_pp_is_active = False

# total_ppがtarget_total_ppより低い場合の再設定 
if target_total_pp <= now_pp:
    print("target_total_pp was lower than the current total_pp.")
    print("target modified: {:,.1f}pp->{:,.1f}pp({:+,.0f}pp). \n\n".format(target_total_pp, now_pp + target_plus_pp,target_plus_pp))
    target_total_pp = now_pp + target_plus_pp
    target_pp_is_active = False


# 個々の+pp算出
target_pp_range_is_active = True
while True:
    dfs = []
    loop_cnt = 0
    for pp_mogmog in range(start_pp, end_pp+1, step):
        list_pp = df_scores['PP'].to_list()#
        list_pp.append(pp_mogmog)
        list_pp.sort(reverse=True)
        index_pp = list_pp.index(pp_mogmog)
        index_weight = pp_mogmog * 0.965 ** index_pp
        total_pp = [list_pp[i] * 0.965 ** i for i in range(len(list_pp))]
        t_pp = sum(total_pp) 
        new_row = {
            'no': index_pp+1, 
            'pp': pp_mogmog, 
            'weight': index_weight,
            'total_pp': t_pp, 
            '+pp':t_pp - now_pp,
            }
        # index_pp+1, pp_mogmog, index_weight, t_pp, t_pp - now_pp))
        new_df = pd.DataFrame(new_row, index=[0])
        dfs.append(new_df)
    
    if (t_pp + (t_pp - now_pp) * int(limit_eat_count/5) > target_total_pp) or loop_cnt == 10:
        break

    end_pp += 20
    start_pp += 20
    loop_cnt += 1
    target_pp_range_is_active = False

if not target_pp_range_is_active:
    print("[caution!!!]")
    print("start_pp and end_pp was lower than the current total_pp.")
    print("range modified: {:,.1f}pp-{:,.1f}pp. \n\n".format(start_pp, end_pp))


style_simulator_format = {
        "no": "{:,.0f}",
        "pp": "{:,.0f}pp",
        "weight": "({:,.2f}pp)",
        "total_pp": "{:,.2f}pp",
        "+pp": "+{:,.2f}pp",
        # "pp(n)": "{:,.2f}pp",
        "total_pp(n)": "{:,.2f}pp",
        "+pp(n)": "+{:,.2f}pp",
}

caption_styles = [dict(selector="caption",
                       props=[
                            ("text-align", "lett"),
                              ("font-size", "150%"),
                              ("border-bottom", "1px solid"),
                              ]
                       )
                  ]


# 結合
df = pd.concat(dfs, ignore_index=True)

# 合計値算出
def func_pp_mogmog(x):
    eat_pp = x[0]
    list_pp = df_scores['PP'].to_list()
    n_count = 0
    t_pp = 0
    weight = "-"

    while t_pp < target_total_pp:
        list_pp.append(eat_pp)
        list_pp.sort(reverse=True)
        total_pp = [list_pp[i] * 0.965 ** i for i in range(len(list_pp))]
        t_pp = sum(total_pp)

        n_count += 1
        if n_count >= limit_eat_count:
            break

    return "{:,.0f}pp x {}".format(eat_pp, n_count), t_pp, (t_pp - now_pp)

df[['pp(n)', 'total_pp(n)','+pp(n)']] = df[['pp','weight','total_pp']].apply(func_pp_mogmog, axis=1, result_type='expand')

# ★-Acc算出
from scipy import interpolate

kmax = curve[0][1]
kmin = curve[-1][1]

def func_pp_acc(row, star):
    pp = row['pp']
    k = pp / (star * c)
    try:
        if (k <= kmax) and (k >= kmin):
            return f_acc_k(k) * 100
        else:
            return "-"
    except:
        print('ex')
        return "err"

curve_c = [curve[i][1] for i in range(len(curve))]
_curve_y_acc = [curve[i][0] for i in range(len(curve))]
f_acc_k = interpolate.interp1d(curve_c, _curve_y_acc)

for star_i in np.arange(start_star, end_star+step_star, step_star):
    # df[['{:,.1f}'.format(star_i)]] = df[['pp']].apply(func_pp_acc, args=(star_i,))
    df['{:,.1f}'.format(star_i)] = df.apply(func_pp_acc, args=(star_i,), axis=1)



df.style.highlight_null(null_color="lightgray" # ).format(style_format)
    ).format(style_simulator_format
    ).set_table_attributes("style='display:inline'"
    ).set_caption("PP Simulation (now:{:,.2f}pp->target:{:,.2f}pp) - {} - {}".format(now_pp, target_total_pp,tz_ja.strftime("%Y.%m.%d"), df_info["name"][0])
    ).set_table_styles(caption_styles)
# Out:
# my star range is auto.:7.1-8.2
# <style type="text/css">
# #T_f4247_ caption {
#   text-align: lett;
#   font-size: 150%;
#   border-bottom: 1px solid;
# }
# </style>
# <table id="T_f4247_" class="dataframe">
#   <caption>PP Simulation (now:8,664.88pp->target:9,000.00pp) - 2023.03.10 - hatopop</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >no</th>
#       <th class="col_heading level0 col1" >pp</th>
#       <th class="col_heading level0 col2" >weight</th>
#       <th class="col_heading level0 col3" >total_pp</th>
#       <th class="col_heading level0 col4" >+pp</th>
#       <th class="col_heading level0 col5" >pp(n)</th>
#       <th class="col_heading level0 col6" >total_pp(n)</th>
#       <th class="col_heading level0 col7" >+pp(n)</th>
#       <th class="col_heading level0 col8" >7.1</th>
#       <th class="col_heading level0 col9" >7.6</th>
#       <th class="col_heading level0 col10" >8.1</th>
#       <th class="col_heading level0 col11" >8.6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4247_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f4247_row0_col0" class="data row0 col0" >75</td>
#       <td id="T_f4247_row0_col1" class="data row0 col1" >280pp</td>
#       <td id="T_f4247_row0_col2" class="data row0 col2" >(20.05pp)</td>
#       <td id="T_f4247_row0_col3" class="data row0 col3" >8,665.25pp</td>
#       <td id="T_f4247_row0_col4" class="data row0 col4" >+0.37pp</td>
#       <td id="T_f4247_row0_col5" class="data row0 col5" >280pp x 100</td>
#       <td id="T_f4247_row0_col6" class="data row0 col6" >8,675.07pp</td>
#       <td id="T_f4247_row0_col7" class="data row0 col7" >+10.19pp</td>
#       <td id="T_f4247_row0_col8" class="data row0 col8" >93.94</td>
#       <td id="T_f4247_row0_col9" class="data row0 col9" >92.80</td>
#       <td id="T_f4247_row0_col10" class="data row0 col10" >91.69</td>
#       <td id="T_f4247_row0_col11" class="data row0 col11" >90.58</td>
#     </tr>
#     <tr>
#       <th id="T_f4247_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f4247_row1_col0" class="data row1 col0" >50</td>
#       <td id="T_f4247_row1_col1" class="data row1 col1" >290pp</td>
#       <td id="T_f4247_row1_col2" class="data row1 col2" >(50.61pp)</td>
#       <td id="T_f4247_row1_col3" class="data row1 col3" >8,666.44pp</td>
#       <td id="T_f4247_row1_col4" class="data row1 col4" >+1.55pp</td>
#       <td id="T_f4247_row1_col5" class="data row1 col5" >290pp x 100</td>
#       <td id="T_f4247_row1_col6" class="data row1 col6" >8,707.97pp</td>
#       <td id="T_f4247_row1_col7" class="data row1 col7" >+43.09pp</td>
#       <td id="T_f4247_row1_col8" class="data row1 col8" >94.50</td>
#       <td id="T_f4247_row1_col9" class="data row1 col9" >93.38</td>
#       <td id="T_f4247_row1_col10" class="data row1 col10" >92.30</td>
#       <td id="T_f4247_row1_col11" class="data row1 col11" >91.24</td>
#     </tr>
#     <tr>
#       <th id="T_f4247_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f4247_row2_col0" class="data row2 col0" >25</td>
#       <td id="T_f4247_row2_col1" class="data row2 col1" >300pp</td>
#       <td id="T_f4247_row2_col2" class="data row2 col2" >(127.58pp)</td>
#       <td id="T_f4247_row2_col3" class="data row2 col3" >8,669.28pp</td>
#       <td id="T_f4247_row2_col4" class="data row2 col4" >+4.40pp</td>
#       <td id="T_f4247_row2_col5" class="data row2 col5" >300pp x 100</td>
#       <td id="T_f4247_row2_col6" class="data row2 col6" >8,786.99pp</td>
#       <td id="T_f4247_row2_col7" class="data row2 col7" >+122.11pp</td>
#       <td id="T_f4247_row2_col8" class="data row2 col8" >95.03</td>
#       <td id="T_f4247_row2_col9" class="data row2 col9" >93.95</td>
#       <td id="T_f4247_row2_col10" class="data row2 col10" >92.89</td>
#       <td id="T_f4247_row2_col11" class="data row2 col11" >91.85</td>
#     </tr>
#     <tr>
#       <th id="T_f4247_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f4247_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_f4247_row3_col1" class="data row3 col1" >310pp</td>
#       <td id="T_f4247_row3_col2" class="data row3 col2" >(209.49pp)</td>
#       <td id="T_f4247_row3_col3" class="data row3 col3" >8,675.00pp</td>
#       <td id="T_f4247_row3_col4" class="data row3 col4" >+10.12pp</td>
#       <td id="T_f4247_row3_col5" class="data row3 col5" >310pp x 100</td>
#       <td id="T_f4247_row3_col6" class="data row3 col6" >8,945.81pp</td>
#       <td id="T_f4247_row3_col7" class="data row3 col7" >+280.93pp</td>
#       <td id="T_f4247_row3_col8" class="data row3 col8" >95.37</td>
#       <td id="T_f4247_row3_col9" class="data row3 col9" >94.48</td>
#       <td id="T_f4247_row3_col10" class="data row3 col10" >93.43</td>
#       <td id="T_f4247_row3_col11" class="data row3 col11" >92.42</td>
#     </tr>
#     <tr>
#       <th id="T_f4247_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f4247_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_f4247_row4_col1" class="data row4 col1" >320pp</td>
#       <td id="T_f4247_row4_col2" class="data row4 col2" >(267.79pp)</td>
#       <td id="T_f4247_row4_col3" class="data row4 col3" >8,682.63pp</td>
#       <td id="T_f4247_row4_col4" class="data row4 col4" >+17.75pp</td>
#       <td id="T_f4247_row4_col5" class="data row4 col5" >320pp x 31</td>
#       <td id="T_f4247_row4_col6" class="data row4 col6" >9,003.91pp</td>
#       <td id="T_f4247_row4_col7" class="data row4 col7" >+339.03pp</td>
#       <td id="T_f4247_row4_col8" class="data row4 col8" >95.66</td>
#       <td id="T_f4247_row4_col9" class="data row4 col9" >95.00</td>
#       <td id="T_f4247_row4_col10" class="data row4 col10" >93.97</td>
#       <td id="T_f4247_row4_col11" class="data row4 col11" >92.97</td>
#     </tr>
#     <tr>
#       <th id="T_f4247_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f4247_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_f4247_row5_col1" class="data row5 col1" >330pp</td>
#       <td id="T_f4247_row5_col2" class="data row5 col2" >(318.45pp)</td>
#       <td id="T_f4247_row5_col3" class="data row5 col3" >8,691.83pp</td>
#       <td id="T_f4247_row5_col4" class="data row5 col4" >+26.94pp</td>
#       <td id="T_f4247_row5_col5" class="data row5 col5" >330pp x 17</td>
#       <td id="T_f4247_row5_col6" class="data row5 col6" >9,014.58pp</td>
#       <td id="T_f4247_row5_col7" class="data row5 col7" >+349.70pp</td>
#       <td id="T_f4247_row5_col8" class="data row5 col8" >95.91</td>
#       <td id="T_f4247_row5_col9" class="data row5 col9" >95.31</td>
#       <td id="T_f4247_row5_col10" class="data row5 col10" >94.46</td>
#       <td id="T_f4247_row5_col11" class="data row5 col11" >93.48</td>
#     </tr>
#     <tr>
#       <th id="T_f4247_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f4247_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_f4247_row6_col1" class="data row6 col1" >340pp</td>
#       <td id="T_f4247_row6_col2" class="data row6 col2" >(340.00pp)</td>
#       <td id="T_f4247_row6_col3" class="data row6 col3" >8,701.61pp</td>
#       <td id="T_f4247_row6_col4" class="data row6 col4" >+36.73pp</td>
#       <td id="T_f4247_row6_col5" class="data row6 col5" >340pp x 11</td>
#       <td id="T_f4247_row6_col6" class="data row6 col6" >9,005.13pp</td>
#       <td id="T_f4247_row6_col7" class="data row6 col7" >+340.25pp</td>
#       <td id="T_f4247_row6_col8" class="data row6 col8" >96.14</td>
#       <td id="T_f4247_row6_col9" class="data row6 col9" >95.59</td>
#       <td id="T_f4247_row6_col10" class="data row6 col10" >94.95</td>
#       <td id="T_f4247_row6_col11" class="data row6 col11" >93.98</td>
#     </tr>
#     <tr>
#       <th id="T_f4247_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f4247_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_f4247_row7_col1" class="data row7 col1" >350pp</td>
#       <td id="T_f4247_row7_col2" class="data row7 col2" >(350.00pp)</td>
#       <td id="T_f4247_row7_col3" class="data row7 col3" >8,711.61pp</td>
#       <td id="T_f4247_row7_col4" class="data row7 col4" >+46.73pp</td>
#       <td id

# %%
#@title ScatterPlot (Stars - Acc/PP)

#@markdown ---
#@markdown <h4>Enable</h4>
scatterplot_is_enable = True #@param {type:"boolean"}

#@markdown ---

#@markdown <h4>Simulation Lines</h4>
simu_line_is_enable = True #@param {type:"boolean"}
simu_line_width = 0.5 #@param {type:"slider", min:0.1, max:15, step:0.1}
simu_line_type = "dot" #@param ["solid", "dot", "dash", "dashdot"]
simu_legend_is_enable = True #@param {type:"boolean"}
#@markdown ---

#@markdown <h4>Taget Lines</h4>
target_line_is_enable = True #@param {type:"boolean"}
target_line_setting_is_auto = True #@param {type:"boolean"}
target_line_width = 1 #@param {type:"slider", min:0.1, max:15, step:0.1}
target_line_type = "solid" #@param ["solid", "dot", "dash", "dashdot"]
target_legend_is_enable = True #@param {type:"boolean"}
target_pps = "330,315,300" #@param {type:"string"}
target_pp_colors = "blue,black,red" #@param {type:"string"}
target_accs = "95,94,92" #@param {type:"string"}
target_acc_colors = "blue,black,red" #@param {type:"string"}
target_stars = "8.4,7.6" #@param {type:"string"}
target_star_colors = "blue, red" #@param {type:"string"}

#@markdown ---
#@markdown <h4>Parameters</h4>

col_x = "Stars" #@param ["Stars"]
col_y = "Acc" #@param ["PP", "Acc"]
size = "Stars" #@param ["PP", "Acc", "Stars", "Rank", "Miss", "Nps", "Njs", "Notes", "Bombs", "Obstacles", "Resets", "Errors", "Warns"]
color = "Recent" #@param ["PP", "Acc", "LevelStr", "AccRank", "Stars", "Days", "Recent","Rank", "Miss", "Nps", "Njs", "Notes", "Bombs", "Obstacles", "Resets", "Errors", "Warns"]

#@markdown ---
#@markdown <h4>Filters</h4>
filtered_star_min = 0 #@param {type:"slider", min:0, max:15, step:1}
filtered_star_max = 15 #@param {type:"slider", min:0, max:15, step:1}
filtered_pp_min = 0 #@param {type:"slider", min:0, max:1000, step:10}
filtered_pp_max = 1000 #@param {type:"slider", min:0, max:1000, step:10}
filtered_acc_min = 80 #@param {type:"slider", min:0, max:100, step:1}
filtered_acc_max = 100 #@param {type:"slider", min:0, max:100, step:1}

# plotly ファイル名設定
plot_name = "ScatterPlot"
config = {
    'toImageButtonOptions': {
        'format': 'png', 
        'filename': "{}_{}_{}".format(plot_name, df_info["name"][0], tz_ja.strftime("%Y%m%d_%H%M%S")),
        'scale': 1 # Multiply title/legend/axis/canvas sizes by this factor
    }
}

# 目標線の自動設定
if target_line_setting_is_auto:
    target_pps = "{},{},{}".format(end_pp,int((start_pp+end_pp)/2),start_pp)
    target_pp_colors = "blue,black,red"
    target_stars = "{},{},{}".format(end_star,(start_star+end_star)/2,start_star)
    target_star_colors = "blue,black,red"

if scatterplot_is_enable:
    import plotly.io as pio

    def _func_Recent(x):
        # print(x)
        if  x <= Recent:
            return "recent".format(Recent)
        else:
            return "old".format(Recent)

    def func_null_exclude(x):
        if len(x[0]) == 0:
            return 0
        else:
            return x[1] 

    df_scatter = df_scores[(df_scores['Ranked']==1)
                    & (df_scores["PP"] >= filtered_pp_min)
                    & (df_scores["PP"] <= filtered_pp_max)
                    & (df_scores["Acc"] >= filtered_acc_min)
                    & (df_scores["Acc"] <= filtered_acc_max)
                    & (df_scores["Stars"] >= filtered_star_min)
                    & (df_scores["Stars"] <= filtered_star_max)]

    df_scatter['Recent'] = df_scatter['Days'].apply(_func_Recent)

    color_map = {"old": "#636EFA", "recent": "#ff4500"}

    fig2 = px.scatter(df_scatter.sort_values(color, ascending=True)
                    , x=col_x, y=col_y, color=color,
                    size=size, 
                    hover_data=["Stars","PP","Acc","AccRank","Score","Miss","Bad","SongName","SongAuthor","LevelAuthor","Difficulty"],
                    color_discrete_map=color_map,
                    width=800, height=800)



    try:
        if df_scatter[color].dtype in ['float64', 'int64']:
            simu_legend_is_enable = False
            target_legend_is_enable = False
    except:
        pass

    # x:star - y:acc
    if simu_line_is_enable and col_x == "Stars" and col_y == "Acc":
        # simu-ppの線
        for target_pp in range(start_pp, end_pp + step, step):
            target_pp = int(target_pp)
            curve_x_star = [target_pp / (curve[i][1] * c) for i in range(len(curve))]
            # x:star, y:acc
            fig2.add_scatter(x = curve_x_star, y = curve_y_acc, mode='lines', name="sim-pp-{}".format(target_pp),
                                showlegend=simu_legend_is_enable, 
                                line=dict(
                                        dash=simu_line_type, 
                                        color='black', 
                                        width=simu_line_width
                                    )
                                )

        # simu-starの線
        for target_star in np.arange(start_star, end_star+step_star, step_star):
            fig2.add_scatter(x = [target_star, target_star], y = [0, 100], mode='lines', name="sim-star-{}".format(target_star),
                                showlegend=simu_legend_is_enable, 
                                line=dict(
                                        dash=simu_line_type, 
                                        color='black', 
                                        width=simu_line_width
                                    )
                                )
            

    # x:star - y:acc
    if target_line_is_enable and col_x == "Stars" and col_y == "Acc":
        # ppの線
        target_pps = target_pps.split(",")
        target_pp_colors = target_pp_colors.split(",")
        for target_pp, target_pp_color in zip(target_pps, target_pp_colors):
            target_pp = int(target_pp)
            curve_x_star = [target_pp / (curve[i][1] * c) for i in range(len(curve))]

            # x:star, y:acc
            fig2.add_scatter(x = curve_x_star, y = curve_y_acc, mode='lines', name="pp-{}".format(target_pp),
                                showlegend=target_legend_is_enable, 
                                line=dict(
                                        dash=target_line_type, 
                                        color=target_pp_color, 
                                        width=target_line_width
                                    )
                                )
        
        # x:star, y:acc
        target_accs = target_accs.split(",")
        target_acc_colors = target_acc_colors.split(",")
        for target_acc, target_acc_color in zip(target_accs, target_acc_colors):
            target_acc = int(target_acc)
            fig2.add_scatter(x = [-1,13], y = [target_acc, target_acc], mode='lines', name="acc-{}".format(target_acc),
                                showlegend=target_legend_is_enable, 
                                line=dict(
                                        dash=target_line_type, 
                                        color=target_acc_color, 
                                        width=target_line_width
                                    )
                                )


        target_stars = target_stars.split(",")
        target_star_colors = target_star_colors.split(",")
        for target_star, target_star_color in zip(target_stars, target_star_colors):
            target_star = float(target_star)
            fig2.add_scatter(x = [target_star, target_star], y = [0, 100], mode='lines', name="star-{}".format(target_star),
                                showlegend=target_legend_is_enable, 
                                line=dict(
                                        dash=target_line_type, 
                                        color=target_star_color, 
                                        width=target_line_width
                                    )
                                )

    # x:star - y:acc
    if simu_line_is_enable and col_x == "Stars" and col_y == "PP":
        # simu-ppの線
        for target_pp in range(start_pp, end_pp + step, step):
            target_pp = int(target_pp)
            curve_x_star = [target_pp / (curve[i][1] * c) for i in range(len(curve))]
            fig2.add_scatter(x = [-1,13], y = [target_pp, target_pp], mode='lines', name="simu-pp-{}".format(target_pp),
                                showlegend=simu_legend_is_enable, 
                                line=dict(
                                        dash=simu_line_type, 
                                        color='black', 
                                        width=simu_line_width
                                    )
                                )

        #simu-starの線
        for target_star in np.arange(start_star, end_star+step_star, step_star):
            fig2.add_scatter(x = [target_star, target_star], y = [0, 1000], mode='lines', name="sim-star-{}".format(target_star),
                                showlegend=simu_legend_is_enable, 
                                line=dict(
                                        dash=simu_line_type, 
                                        color='black', 
                                        width=simu_line_width
                                    )
                                )

    # x:star - y:pp            
    if target_line_is_enable and col_x == "Stars" and col_y == "PP":
        # ppの線
        target_pps = target_pps.split(",")
        target_pp_colors = target_pp_colors.split(",")
        for target_pp, target_pp_color in zip(target_pps, target_pp_colors):

            target_pp = int(target_pp)

            # x:star, y:acc
            fig2.add_scatter(x = [-1,13], y = [target_pp, target_pp], mode='lines', name="pp-{}".format(target_pp),
                                showlegend=target_legend_is_enable, 
                                line=dict(
                                        dash=target_line_type, 
                                        color=target_pp_color, 
                                        width=target_line_width
                                    )
                                )
        
        # accの線
        from scipy import interpolate
        _curve_y_acc = [curve[i][0] for i in range(len(curve))]
        fleg = interpolate.interp1d(_curve_y_acc, curve_c)
        target_accs = target_accs.split(",")
        target_acc_colors = target_acc_colors.split(",")
        for target_acc, target_acc_color in zip(target_accs, target_acc_colors):
            target_acc = int(target_acc)

            k = fleg(target_acc/100)
            _xs = np.arange(-1, 13, 0.5)
            pp = [x * c * k for x in _xs]

            fig2.add_scatter(x = _xs, y = pp, mode='lines', name="acc-{}".format(target_acc),
                                showlegend=target_legend_is_enable, 
                                line=dict(
                                        dash=target_line_type, 
                                        color=target_acc_color, 
                                        width=target_line_width
                                    )
                                )
            
        # star
        target_stars = target_stars.split(",")
        target_star_colors = target_star_colors.split(",")
        for target_star, target_star_color in zip(target_stars, target_star_colors):
            target_star = float(target_star)
            fig2.add_scatter(x = [target_star, target_star], y = [0, 1000], mode='lines', name="star-{}".format(target_star),
                                showlegend=target_legend_is_enable, 
                                line=dict(
                                        dash=target_line_type, 
                                        color=target_star_color, 
                                        width=target_line_width
                                    )
                                )



    fig2.update_layout(title="Ranked - ScatterPlot Analysis - {} - {}".format(tz_ja.strftime("%Y.%m.%d"), df_info["name"][0]), title_x=0.5,
                xaxis_title = "x:{} (markersize:{}, markercolor:{})".format(col_x, size, color), yaxis_title="y:{}".format(col_y)
                )
    

    diff_x = (df_scatter[col_x].max() - df_scatter[col_x].min()) / 20
    diff_y = (df_scatter[col_y].max() - df_scatter[col_y].min()) / 20

    fig2.update_layout(
                    xaxis=dict(
                        range=(df_scatter[col_x].min()-diff_x, df_scatter[col_x].max()+diff_x)
                        ),
                    yaxis=dict(
                        range=(df_scatter[col_y].min()-diff_y, df_scatter[col_y].max()+diff_y)
                        ),
    )

    fig2.show(config=config)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1409a917-166f-4529-b0a1-035f52a57747" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1409a917-166f-4529-b0a1-035f52a57747")) {                    Plotly.newPlot(                        "1409a917-166f-4529-b0a1-035f52a57747",                        [{"customdata":[[191.7563,"SS+95",605638,0,0,"Waifu","S3RL & Alaguan","fqrb","Expert"],[153.7312,"SS",983779,6,2,"Half Of It","Abraxis, Seven Lions & Dimibo","jafdy","Expert"],[150.4704,"SS",809212,4,4,"I CAN'T STOP ME","TWICE","Sotarks","Expert"],[171.1125,"SS",1069459,2,1,"Come Alive","Pendulum","Fatalution","Expert"],[83.31247,"SS+95",442419,0,0,"Sandstorm","Darude","Skyler Wallace","Normal"],[85.67639,"SS+95",318554,0,0,"You Are the End","","Waveshaper","Hard"],[81.41187,"SS+95",399760,0,0,"Majesty (ft. Veela)","Ben Moon","ManDynasty","Normal"],[82.50684,"SS+95",123616,0,0,"Armada","Skies of Arcadia OST","RinkuSenpai","Normal"],[237.9624,"SS",727339,7,3,"Fire Blazing","Dropgun","Teuflum","ExpertPlus"],[167.8467,"SS",408368,0,0,"Metal Bat","RoomTone","ThyYeet vs. Jhintleman","Hard"],[174.5229,"SS",1222535,0,0,"Ding Dong Song","Gunther & The Sunshine Girls","Teuflum","Expert"],[186.5757,"SS",986546,1,0,"Quasar Dreams","Fvrwvrd","ComplexFrequency & Fvrwvrd","Normal"],[182.7139,"SS+95",315689,0,0,"Toilet","Clown Core","Fatalution","Expert"],[191.9045,"SS+95",810549,0,0,"Crisis","Twista ft. Tech N9ne","Checkthepan","Hard"],[179.505,"SS",238713,0,0,"Granat","Drop","Rigid","ExpertPlus"],[168.2779,"SS",803193,2,1,"Digital Girl","KIRA","Skeelie","Expert"],[193.5166,"SS",849067,0,0,"LIKEY","TWICE","simplymarvellous","ExpertPlus"],[172.1509,"SS",642821,2,1,"BOY","TREASURE","Bloodcloak","ExpertPlus"],[212.7141,"SS+95",456516,0,0,"I still think about y\u200b%\u200b#'\u200b(\u200b)\u200b_\u200b*\u200b{\u200b\\\u200b\\\u200b\"'&36\u200b)\u200b%\u200b(\u200b\"'\u200b$\u200b&''&\u200b(\u200b15y\u200b!\u200b!\u200b!\u200b_\u200b?\u200b?\u200b*\u200b`\u200b~\u200b\u200b","t+pazolite","Vilawes","ExpertPlus"],[214.1543,"SS+95",737527,0,0,"Better Not","Louis The Child","Olaf","Expert"],[170.7397,"SS",858078,2,0,"Hoshikuzu Struck","t+pazolite","HappieBTW","Hard"],[177.8617,"SS+95",819244,0,0,"Quasar Dreams","Fvrwvrd","ComplexFrequency & Fvrwvrd","Easy"],[185.7034,"SS+95",1135433,0,0,"YELL!","DJ Genki VS Camellia","Joshabi","Hard"],[169.004,"SS",780328,2,2,"Nautilus","Yorushika","SmileEaglet","Expert"],[237.9106,"SS",1287446,5,0,"The Imperial March","Celldweller","Fvrwvrd & FatBeanzoop","Expert"],[92.48908,"SS+95",446215,0,0,"THE DROP","Gammer","Teuflum","Easy"],[88.66386,"SS+95",527705,0,0,"Still in my heart","PSYQUI","That_Narwhal","Normal"],[112.8281,"SS+95",295672,0,0,"Sad Spring","Draw The Emotional & Foreground Eclipse","Scrappy","Easy"],[85.61942,"SS+95",471992,0,0,"Digital Girl","KIRA","Skeelie","Normal"],[88.15802,"SS+95",459731,0,0,"Meowchine","Azazal & MachineDoll","CyanSnow","Normal"],[257.2271,"SS",1112097,6,3,"Just Don't Mind","Fox Stevenson","Jaack & Joshabi","Expert"],[190.3666,"SS",756851,2,2,"Just Don't Mind","Fox Stevenson","Jaack & Joshabi","Hard"],[195.9476,"SS+95",574320,0,0,"Dear Future Husband","Meghan Trainor","GianniKoch","Expert"],[159.3561,"SS",432054,1,0,"Quietus","P*Light","miitchel","Expert"],[137.6223,"SS",425718,5,0,"The Way You Are","Aftermath","Vinabby & SSnowy","ExpertPlus"],[192.631,"SS",657826,1,0,"Farewell","Xystran","Shark","Expert"],[98.72831,"SS+95",418329,0,0,"Pretty Pretty Dark","Adust Rain","Scrappy","Easy"],[96.36245,"SS+95",320690,0,0,"Ruma","Kairiki Bear","MaNaB & Emir","Easy"],[96.99442,"SS+95",455999,0,0,"DONUT HOLE","Hachi","Kizuflux & Uninstaller","Easy"],[93.03113,"SS+95",431525,0,0,"Start of the Determination","Kobaryo","Paper_Core","Normal"],[91.40594,"SS+ ...

# %% [markdown]
# ## S2: Playlist Simulation

# %%
#@title Get Target Players Data
#@markdown <h4>Enable</h4>
saved_target_scores_is_enable = True #@param {type:"boolean"}
saved_ranking_data_is_enable = True #@param {type:"boolean"}
target_player_count = 20 #@param {type:"slider", min:1, max:20, step:1}
target_pp_search_range = 200 #@param {type:"slider", min:50, max:1000, step:50}
target_stats_is_enable = True #@param {type:"boolean"}
# import math

ranking_data_pickle_path = r"{}_ranking_data_{}_pp_{}.pkl".format(player_path, player_id, target_total_pp)
target_scores_pickle_path = r"{}_target_scores_{}_pp_{}.pkl".format(player_path, player_id, target_total_pp)

# player_score_pickle_path = r"{}/scores_full_{}.pkl".format(player_path, player_id)

if saved_ranking_data_is_enable and os.path.isfile(ranking_data_pickle_path):
    df_player_ranking_pkl = pd.read_pickle(ranking_data_pickle_path)
    df_player_ranking = df_player_ranking_pkl.copy()
    pass

else:
    # Player Rankingの新規取得
    RankPageCount = math.ceil(df_info["rank"][0]/50)
    url = r"https://scoresaber.com/api/players?page=1&withMetadata=true"
    response = requests.get(url)
    res_data = response.json()
    df_player_ranking = json_normalize(res_data['players'])

    for i in tqdm(range(2, RankPageCount)):
        url = r"https://scoresaber.com/api/players?page={}&withMetadata=true".format(i)
        try:
            response = requests.get(url)
            res_data = response.json()
            df_player_ranking=df_player_ranking.append(json_normalize(res_data['players']), ignore_index=True)
        except:
            break

    # 未加工データ保存 
    df_player_ranking.to_pickle(ranking_data_pickle_path)

# Player Rankingからターゲットプレイヤーのランダムpick up
df_target_players = df_player_ranking[(1==1)
    &(df_player_ranking['pp'] >= target_total_pp)
    &(df_player_ranking['pp'] < target_total_pp+target_pp_search_range)
    ].sample(n=target_player_count)

df_target_players["TotalScore"] = df_target_players["scoreStats.totalScore"]
df_target_players["RankedScore"] = df_target_players["scoreStats.totalRankedScore"]
df_target_players["AveRankedAcc"] = df_target_players["scoreStats.averageRankedAccuracy"]
df_target_players["TotalPlay"] = df_target_players["scoreStats.totalPlayCount"]
df_target_players["RankedPlay"] = df_target_players["scoreStats.rankedPlayCount"]
df_target_players["ReplayWatched"] = df_target_players["scoreStats.replaysWatched"]


cols_target = ['id', 'name', 
    'country', 'pp', 'rank',
    'countryRank',
    'AveRankedAcc', 
    'TotalPlay',
    'RankedPlay',
    ]

# -----------------------------
# get target_players score
# -----------------------------
if saved_target_scores_is_enable and os.path.isfile(target_scores_pickle_path):
    df_target_scores_pkl = pd.read_pickle(target_scores_pickle_path)
    df_target_scores = df_target_scores_pkl.copy()
    pass
else:
    player_ids = df_target_players['id'].to_list()
    url = r"https://scoresaber.com/api/player/{}/scores?sort=top&limit={}".format(player_ids[0], page_count)
    response = requests.get(url)
    res_data = response.json()
    df_target_scores = json_normalize(res_data['playerScores'])

    for i in tqdm(range(1, len(player_ids))):
        url = r"https://scoresaber.com/api/player/{}/scores?sort=top&limit={}".format(player_ids[i], page_count)
        try:
            response = requests.get(url)
            res_data = response.json()
            df_target_scores=df_target_scores.append(json_normalize(res_data['playerScores']), ignore_index=True)
        except:
            break

    # 未加工データ保存
    df_target_scores.to_pickle(target_scores_pickle_path)

# 加工
df_target_scores['Song'] = df_target_scores['leaderboard.songName'] + " " + df_target_scores['leaderboard.songSubName'] + " / " + df_target_scores['leaderboard.songAuthorName'] + " [" + df_target_scores['leaderboard.levelAuthorName'] + "]"
df_target_scores['SongName'] = df_target_scores['leaderboard.songName']
df_target_scores['SongSub'] = df_target_scores['leaderboard.songSubName']
df_target_scores['SongAuthor'] = df_target_scores['leaderboard.songAuthorName']
df_target_scores['LevelAuthor'] = df_target_scores['leaderboard.levelAuthorName']
df_target_scores['Hash'] = df_target_scores['leaderboard.songHash'].str.upper()

def func_higher_score(x):
    try:
        if x[0] >= x[1]:
            return x[0]
        else:
            return x[1]
    except:
        return x[1]

if score_mode == "BaseScore":
    df_target_scores['Score'] = df_target_scores['score.baseScore']
elif score_mode == "ModifiedScore":
    df_target_scores['Score'] = df_target_scores['score.modifiedScore']
elif score_mode == "HigherScore":
    df_target_scores['Score'] = df_target_scores[['score.baseScore','score.modifiedScore']].apply(func_higher_score, axis=1)
else:
    df_target_scores['Score'] = df_target_scores['score.modifiedScore']

df_target_scores['Acc'] = df_target_scores['Score'] / df_target_scores['leaderboard.maxScore'] * 100
# df_target_scores['Acc'] = df_target_scores['score.modifiedScore'] / df_target_scores['leaderboard.maxScore'] * 100
df_target_scores['MaxScore'] = df_target_scores['leaderboard.maxScore']

df_target_scores['Mode'] = df_target_scores['leaderboard.difficulty.gameMode'].apply(func_mode)
#df_target_scores['Mode'] = df_target_scores['leaderboard.difficulty.gameMode']
_df_target_scores = df_target_scores['leaderboard.difficulty.difficultyRaw'].str.split('_', expand=True)
_df_target_scores.columns = ['_','Difficulty', 'Mode']
df_target_scores['Difficulty'] = _df_target_scores['Difficulty']
df_target_scores['Stars'] = df_target_scores['leaderboard.stars']
df_target_scores['Level'] = df_target_scores['Stars'].astype('int')
df_target_scores["LevelStr"] = df_target_scores['Level'].astype('str')
# df_target_scores['Score'] = df_target_scores['score.modifiedScore']
df_target_scores['Bad'] = df_target_scores['score.badCuts']
df_target_scores['Miss'] = df_target_scores['score.missedNotes']
df_target_scores['Combo'] = df_target_scores['score.maxCombo']
df_target_scores['PP'] = df_target_scores['score.pp']
df_target_scores['PPWeight'] = df_target_scores['score.pp'] * df_target_scores['score.weight']
df_target_scores['Rank'] = df_target_scores['score.rank']
df_target_scores['Modifiers'] = df_target_scores['score.modifiers']
df_target_scores['Ranked'] = df_target_scores['leaderboard.ranked']
df_target_scores['Qualified'] = df_target_scores['leaderboard.qualified']
df_target_scores['Play'] = df_target_scores['leaderboard.plays']
df_target_scores['DailyPlay'] = df_target_scores['leaderboard.dailyPlays']
df_target_scores['DateUtc'] = pd.to_datetime(df_target_scores['score.timeSet'])
_df_target_scores_idx = df_target_scores.set_index('DateUtc')
df_target_scores['DateJa'] = _df_target_scores_idx.index.tz_convert(timezone)
df_target_scores['Date'] = df_target_scores['DateJa'].dt.date
df_target_scores['Days'] = (tz_ja.date() - df_target_scores['Date']).dt.days
df_target_scores = df_target_scores.set_index('DateJa')
df_target_scores['Months'] = (df_target_scores['Days'] / 30).astype('int')
df_target_scores['DaysStr'] = df_target_scores['Days'].astype('str')
df_target_scores['MonthsStr'] = df_target_scores['Months'].astype('str')

df_target_scores['Recent'] = df_target_scores['Days'].apply(func_Recent)
df_target_scores['RecentStr'] = df_target_scores['Recent'].astype('str')

df_target_scores['AccRank'] = df_target_scores['Acc'].apply(func_score)

df_target_scores['Cover'] = '<img src="'+df_target_scores['leaderboard.coverImage']+'" style="width:{}px;"/>'.format(cover_image_size)

df_target_scores['FC'] = df_target_scores['score.fullCombo'].apply(func_fc)

df_target_scores = df_target_scores[[x for x in df_target_scores.columns if not x.startswith("score.")]]
df_target_scores = df_target_scores[[x for x in df_target_scores.columns if not x.startswith("leaderboard.")]]


# 結合前Score情報の抽出(LevelClearedProgress用)
df_target_scores_org = df_target_scores.copy()

# 改行コード等の除去
for col in df_target_scores.columns:
    try:
        if len(df_target_scores[df_target_scores[col].str.contains("\n")][[col]]) == 0:
            continue
        else:
            df_target_scores[col] = df_target_scores[col].str.replace("\n","")
    except:
        continue

for col in df_target_scores.columns:
    try:
        if len(df_target_scores[df_target_scores[col].str.contains("\r")][[col]]) == 0:
            continue
        else:
            df_target_scores[col] = df_target_scores[col].str.replace("\r","")
    except:
        continue

df_target_scores = df_target_scores.reset_index()
df_target_scores = pd.merge(df_target_scores, df_rankmap_data, on=["Hash", "Difficulty"], how="left", suffixes=("", "_y"))
df_target_scores = df_target_scores[[x for x in df_target_scores.columns if not x.endswith("_y")]]
df_target_scores = df_target_scores.set_index("DateJa")

#Score情報の保存
df_target_scores = df_target_scores[(df_target_scores['Ranked'] == True)].sort_index(ascending=False)

print('target playersとscoresを取得しました.:{}'.format(len(df_target_players[cols_target])))

display(df_target_players[cols_target].style.set_table_styles(styles_data
                                                ).format(style_format
                                                ).set_caption("target:{:,.0f}pp - {} players picked up - {}".format(target_total_pp, len(df_target_players[cols_target]),tz_ja.strftime("%Y.%m.%d"))#, df_info["name"][0])
                                                ).set_table_styles(caption_styles)
)

if target_stats_is_enable:
    print("")
    # -----------------------------
    # get target_players stats
    # -----------------------------
    from math import ceil
    cols_temp = ["Stars","PP","Acc","Nps","Njs","Duration","Notes","Miss"]
    df_target_scores_top_pp = df_target_scores[cols_temp].sort_values("PP", ascending=False).reset_index(drop=True)# .describe()

    star_mean = df_target_scores_top_pp["Stars"].mean()
    star_std =df_target_scores_top_pp["Stars"].std()
    nps_mean = df_target_scores_top_pp["Nps"].mean()
    nps_std =df_target_scores_top_pp["Nps"].std()
    njs_mean = df_target_scores_top_pp["Njs"].mean()
    njs_std =df_target_scores_top_pp["Njs"].std()

    df_target_scores_top_pp.reset_index(drop=True)
    df_target_stats = df_target_scores_top_pp.describe()#.drop('count', inplace=True)
    df_target_stats.drop('count', inplace=True)
        
    # caption_msg = "My Top 50 PPs Stats - {} - {}".format(tz_ja.strftime("%Y.%m.%d"), df_info["name"][0])
    caption_msg = "Target {} Players - Top 100 PPs Stats".format(len(df_target_players[cols_target]))#, df_info["name"][0])

    display(df_target_stats.style.set_table_styles(styles_data
                                            # ).background_gradient(subset=['+PP'], cmap='coolwarm'
                                            ).format(style_format
                                            ).set_caption(caption_msg #"Playlist Simulation (now:{:,.2f}pp->target:{:,.2f}pp) - method:{} - {} - {}".format(now_pp, target_total_pp, pp_eat_target, tz_ja.strftime("%Y.%m.%d"), df_info["name"][0])
                                            ).set_table_styles(caption_styles)
    )

    print("\n")

    # import pandas as pd

    # star_start = ceil((star_mean - star_std)*10)/10
    # star_end = round(star_mean + star_std, 1)

    # DataFrameを作成
    stats2 = {
            'star_start': [ceil((star_mean - star_std)*10)/10],
            'star_end': [round(star_mean + star_std, 1)],
            'nps_start': [ceil((nps_mean - nps_std)*10)/10],
            'nps_end': [round(nps_mean + nps_std, 1)],
            'njs_start': [ceil((njs_mean - njs_std))],
            'njs_end': [round(njs_mean + njs_std, 0)],
            'Player': ["Target"],        
            }

    df_target_stats2 = pd.DataFrame(stats2)

    def func_stats_2(x):
        star_start = x[0]
        star_end = x[1]
        nps_start = x[2]
        nps_end = x[3]
        njs_start = x[4]
        njs_end = x[5]
        return "{:,.1f}-{:,.1f}★".format(star_start, star_end),"{:,.1f}-{:,.1f}".format(nps_start, nps_end),"{:,.0f}-{:,.0f}".format(njs_start, njs_end)


    df_target_stats2[['Stars', 'Nps', 'Njs']] = df_target_stats2.apply(func_stats_2, axis=1, result_type='expand')

    df_target_stats_result = pd.concat([df_target_stats2, df_stats2], axis=0).reset_index(drop=True)

    caption_msg = "Target vs My Eat Range"

    display(df_target_stats_result[['Stars', 'Nps', 'Njs','Player']].style.set_table_styles(styles_data
                                            ).set_caption(caption_msg
                                            ).set_table_styles(caption_styles)
    )


    # display(df_stats2[['Stars', 'Nps', 'Njs','Player']].style.set_table_styles(styles_data
    #                                         ).set_caption(caption_msg
    #                                         ).set_table_styles(caption_styles)
# Out:
# target playersとscoresを取得しました.:20
# <style type="text/css">
# #T_119b0_ caption {
#   text-align: lett;
#   font-size: 150%;
#   border-bottom: 1px solid;
# }
# </style>
# <table id="T_119b0_" class="dataframe">
#   <caption>target:9,000pp - 20 players picked up - 2023.03.10</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >country</th>
#       <th class="col_heading level0 col3" >pp</th>
#       <th class="col_heading level0 col4" >rank</th>
#       <th class="col_heading level0 col5" >countryRank</th>
#       <th class="col_heading level0 col6" >AveRankedAcc</th>
#       <th class="col_heading level0 col7" >TotalPlay</th>
#       <th class="col_heading level0 col8" >RankedPlay</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_119b0_level0_row0" class="row_heading level0 row0" >2065</th>
#       <td id="T_119b0_row0_col0" class="data row0 col0" >76561197982030204</td>
#       <td id="T_119b0_row0_col1" class="data row0 col1" >Haky</td>
#       <td id="T_119b0_row0_col2" class="data row0 col2" >CZ</td>
#       <td id="T_119b0_row0_col3" class="data row0 col3" >9,039.43pp</td>
#       <td id="T_119b0_row0_col4" class="data row0 col4" >#2,066</td>
#       <td id="T_119b0_row0_col5" class="data row0 col5" >#15</td>
#       <td id="T_119b0_row0_col6" class="data row0 col6" >87.93%</td>
#       <td id="T_119b0_row0_col7" class="data row0 col7" >629</td>
#       <td id="T_119b0_row0_col8" class="data row0 col8" >395</td>
#     </tr>
#     <tr>
#       <th id="T_119b0_level0_row1" class="row_heading level0 row1" >2074</th>
#       <td id="T_119b0_row1_col0" class="data row1 col0" >76561198255500911</td>
#       <td id="T_119b0_row1_col1" class="data row1 col1" >OrdinaryTable</td>
#       <td id="T_119b0_row1_col2" class="data row1 col2" >DE</td>
#       <td id="T_119b0_row1_col3" class="data row1 col3" >9,030.97pp</td>
#       <td id="T_119b0_row1_col4" class="data row1 col4" >#2,075</td>
#       <td id="T_119b0_row1_col5" class="data row1 col5" >#107</td>
#       <td id="T_119b0_row1_col6" class="data row1 col6" >85.92%</td>
#       <td id="T_119b0_row1_col7" class="data row1 col7" >1,320</td>
#       <td id="T_119b0_row1_col8" class="data row1 col8" >373</td>
#     </tr>
#     <tr>
#       <th id="T_119b0_level0_row2" class="row_heading level0 row2" >2096</th>
#       <td id="T_119b0_row2_col0" class="data row2 col0" >2628493580501617</td>
#       <td id="T_119b0_row2_col1" class="data row2 col1" >KayceeKC</td>
#       <td id="T_119b0_row2_col2" class="data row2 col2" >US</td>
#       <td id="T_119b0_row2_col3" class="data row2 col3" >9,005.65pp</td>
#       <td id="T_119b0_row2_col4" class="data row2 col4" >#2,097</td>
#       <td id="T_119b0_row2_col5" class="data row2 col5" >#867</td>
#       <td id="T_119b0_row2_col6" class="data row2 col6" >86.97%</td>
#       <td id="T_119b0_row2_col7" class="data row2 col7" >1,240</td>
#       <td id="T_119b0_row2_col8" class="data row2 col8" >182</td>
#     </tr>
#     <tr>
#       <th id="T_119b0_level0_row3" class="row_heading level0 row3" >2076</th>
#       <td id="T_119b0_row3_col0" class="data row3 col0" >76561199096028752</td>
#       <td id="T_119b0_row3_col1" class="data row3 col1" >CozzieVR</td>
#       <td id="T_119b0_row3_col2" class="data row3 col2" >US</td>
#       <td id="T_119b0_row3_col3" class="data row3 col3" >9,026.90pp</td>
#       <td id="T_119b0_row3_col4" class="data row3 col4" >#2,077</td>
#       <td id="T_119b0_row3_col5" class="data row3 col5" >#857</td>
#       <td id="T_119b0_row3_col6" class="data row3 col6" >88.95%</td>
#       <td id="T_119b0_row3_col7" class="data row3 col7" >577</td>
#       <td id="T_119b0_row3_col8" class="data row3 col8" >193</td>
#     </tr>
#     <tr>
#       <th id="T_119b0_level0_row4" class="row_heading level0 row4" >2053</th>
#       <td id="T_119b0_row4_col0" class="data row4 col0" >76561198039141149</td>
#       <td id="T_119b0_row4_col1" class="data row4 col1" >DavySW</td>
#       <td id="T_119b0_row4_col2" class="data row4 col2" >BE</td>
#       <td id="T_119b0_row4_col3" class="data row4 col3" >9,067.54pp</td>
#       <td id="T_119b0_row4_col4" class="data row4 col4" >#2,054</td>
#       <td id="T_119b0_row4_col5" class="data row4 col5" >#25</td>
#       <td id="T_119b0_row4_col6" class="data row4 col6" >90.63%</td>
#       <td id="T_119b0_row4_col7" class="data row4 col7" >1,209</td>
#       <td id="T_119b0_row4_col8" class="data row4 col8" >540</td>
#     </tr>
#     <tr>
#       <th id="T_119b0_level0_row5" class="row_heading level0 row5" >1995</th>
#       <td id="T_119b0_row5_col0" class="data row5 col0" >76561199186039014</td>
#       <td id="T_119b0_row5_col1" class="data row5 col1" >XD_ERK</td>
#       <td id="T_119b0_row5_col2" class="data row5 col2" >AU</td>
#       <td id="T_119b0_row5_col3" class="data row5 col3" >9,144.06pp</td>
#       <td id="T_119b0_row5_col4" class="data row5 col4" >#1,996</td>
#       <td id="T_119b0_row5_col5" class="data row5 col5" >#57</td>
#       <td id="T_119b0_row5_col6" class="data row5 col6" >92.03%</td>
#       <td id="T_119b0_row5_col7" class="data row5 col7" >202</td>
#       <td id="T_119b0_row5_col8" class="data row5 col8" >100</td>
#     </tr>
#     <tr>
#       <th id="T_119b0_level0_row6" class="row_heading level0 row6" >2004</th>
#       <td id="T_119b0_row6_col0" class="data row6 col0" >76561198795608884</td>
#       <td id="T_119b0_row6_col1" class="data row6 col1" >WSzwach</td>
#       <td id="T_119b0_row6_col2" class="data row6 col2" >PL</td>
#       <td id="T_119b0_row6_col3" class="data row6 col3" >9,133.85pp</td>
#       <td id="T_119b0_row6_col4" class="data row6 col4" >#2,005</td>
#       <td id="T_119b0_row6_col5" class="data row6 col5" >#40</td>
#       <td id="T_119b0_row6_col6" class="data row6 col6" >90.22%</td>
#       <td id="T_119b0_row6_col7" class="data row6 col7" >595</td>
#       <td id="T_119b0_row6_col8" class="data row6 col8" >139</td>
#     </tr>
#     <tr>
#       <th id="T_119b0_level0_row7" class="row_heading level0 row7" >2071</th>
#       <td id="T_119b0_row7_col0" class="data row7 col0" >76561199033653351</td>
#       <td id="T_119b0_row7_col1" class="data row7 col1" >Default Grip | Olstar123</td>
#       <td id="T_119b0_row7_col2" class="data row7 col2" >GB</td>
#       <td id="T_119b0_row7_col3" class="data row7 col3" >9,034.27pp</td>
#       <td id="T_119b0_row7_col4" class="data row7 col4" >#2,072</td>
#       <td id="T_119b0_row7_col5" class="data row7 col5" >#154</td>
#       <td id="T_119b0_row7_col6" class="data row7 col6" >86.33%</td>
#       <td id="T_119b0_row7_col7" class="data row7 col7" >449</td>
#       <td id="T_119b0_row7_col8" class="data row7 col8" >261</td>
#     </tr>
#     <tr>
#       <th id="T_119b0_level0_row8" class="row_heading level0 row8" >2086</th>
#       <td id="T_119b0_row8_col0" class="data row8 col0" >76561198128848067</td>
#       <td id="T_119b0_row8_col1" class="data row8 col1" >DDunkler</td>
#       <td id="T_119b0_row8_col2" class="data row8 col2" >DE</td>
#       <td id="T_119b0_row8_col3" class="data row8 col3" >9,015.28pp</td>
#       <td id="T_119b0_row8_col4" class="data row8 col4" >#2,087</td>
#       <td id="T_119b0_row8_col5" class="data row8 col5" >#109</td>
#       <td id="T_119b0_row8_col6" class="data row8 col6" >92.98%</td>
#       <td id="T_119b0_row8_col7" class="data row8 col7" >1,750</td>
#       <td id="T_119b0_row8_col8" class="data row8 col8" >1,384</td>
#     </tr>
#     <tr>
#       <th id="T_119b0_level0_row9" class="row_heading level0 row9" >2070</th>
#       <td id="T_119b0_row9_col0" class="data row9 col0" >76561198169926007</td>
#       <td id="T_119b0_row9_col1" class="data row9 col1" >EgLdYwSw</td>
#       <td id="T_119b0_row9_col2" class="data row9 col2" >US</td>
#       <td id="T_119b0_row9_col3" class="data row9 col3" >9,035.39pp</td>
#       <td id="T_119b0_row9_col4" class="data row9 col4" >#2,071</td>
#       <td id="T_119b0_row9_col5" class="data row9 col5" >#853</td>
#       <td id="T_119b0_row9_col6" class="data row9 col6" >93.33%</td>
#       <td id="T_119b0_row9_col7" class="data row9 col7" >415</td>
# <style type="text/css">
# #T_d399a_ caption {
#   text-align: lett;
#   font-size: 150%;
#   border-bottom: 1px solid;
# }
# </style>
# <table id="T_d399a_" class="dataframe">
#   <caption>Target 20 Players - Top 100 PPs Stats</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Stars</th>
#       <th class="col_heading level0 col1" >PP</th>
#       <th class="col_heading level0 col2" >Acc</th>
#       <th class="col_heading level0 col3" >Nps</th>
#       <th class="col_heading level0 col4" >Njs</th>
#       <th class="col_heading level0 col5" >Duration</th>
#       <th class="col_heading level0 col6" >Notes</th>
#       <th class="col_heading level0 col7" >Miss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d399a_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_d399a_row0_col0" class="data row0 col0" >8.45★</td>
#       <td id="T_d399a_row0_col1" class="data row0 col1" >300.72pp</td>
#       <td id="T_d399a_row0_col2" class="data row0 col2" >92.14%</td>
#       <td id="T_d399a_row0_col3" class="data row0 col3" >8.24</td>
#       <td id="T_d399a_row0_col4" class="data row0 col4" >20</td>
#       <td id="T_d399a_row0_col5" class="data row0 col5" >213</td>
#       <td id="T_d399a_row0_col6" class="data row0 col6" >1,672</td>
#       <td id="T_d399a_row0_col7" class="data row0 col7" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d399a_level0_row1" class="row_heading level0 row1" >std</th>
#       <td id="T_d399a_row1_col0" class="data row1 col0" >1.35★</td>
#       <td id="T_d399a_row1_col1" class="data row1 col1" >23.28pp</td>
#       <td id="T_d399a_row1_col2" class="data row1 col2" >2.74%</td>
#       <td id="T_d399a_row1_col3" class="data row1 col3" >1.79</td>
#       <td id="T_d399a_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_d399a_row1_col5" class="data row1 col5" >73</td>
#       <td id="T_d399a_row1_col6" class="data row1 col6" >692</td>
#       <td id="T_d399a_row1_col7" class="data row1 col7" >7</td>
#     </tr>
#     <tr>
#       <th id="T_d399a_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_d399a_row2_col0" class="data row2 col0" >2.37★</td>
#       <td id="T_d399a_row2_col1" class="data row2 col1" >216.81pp</td>
#       <td id="T_d399a_row2_col2" class="data row2 col2" >79.40%</td>
#       <td id="T_d399a_row2_col3" class="data row2 col3" >2.18</td>
#       <td id="T_d399a_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_d399a_row2_col5" class="data row2 col5" >32</td>
#       <td id="T_d399a_row2_col6" class="data row2 col6" >291</td>
#       <td id="T_d399a_row2_col7" class="data row2 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d399a_level0_row3" class="row_heading level0 row3" >25%</th>
#       <td id="T_d399a_row3_col0" class="data row3 col0" >7.56★</td>
#       <td id="T_d399a_row3_col1" class="data row3 col1" >287.00pp</td>
#       <td id="T_d399a_row3_col2" class="data row3 col2" >90.57%</td>
#       <td id="T_d399a_row3_col3" class="data row3 col3" >7.04</td>
#       <td id="T_d399a_row3_col4" class="data row3 col4" >19</td>
#       <td id="T_d399a_row3_col5" class="data row3 col5" >150</td>
#       <td id="T_d399a_row3_col6" class="data row3 col6" >1,163</td>
#       <td id="T_d399a_row3_col7" class="data row3 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d399a_level0_row4" class="row_heading level0 row4" >50%</th>
#       <td id="T_d399a_row4_col0" class="data row4 col0" >8.39★</td>
#       <td id="T_d399a_row4_col1" class="data row4 col1" >300.64pp</td>
#       <td id="T_d399a_row4_col2" class="data row4 col2" >92.46%</td>
#       <td id="T_d399a_row4_col3" class="data row4 col3" >8.06</td>
#       <td id="T_d399a_row4_col4" class="data row4 col4" >20</td>
#       <td id="T_d399a_row4_col5" class="data row4 col5" >211</td>
#       <td id="T_d399a_row4_col6" class="data row4 col6" >1,544</td>
#       <td id="T_d399a_row4_col7" class="data row4 col7" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d399a_level0_row5" class="row_heading level0 row5" >75%</th>
#       <td id="T_d399a_row5_col0" class="data row5 col0" >9.33★</td>
#       <td id="T_d399a_row5_col1" class="data row5 col1" >314.92pp</td>
#       <td id="T_d399a_row5_col2" class="data row5 col2" >94.03%</td>
#       <td id="T_d399a_row5_col3" class="data row5 col3" >9.36</td>
#       <td id="T_d399a_row5_col4" class="data row5 col4" >22</td>
#       <td id="T_d399a_row5_col5" class="data row5 col5" >260</td>
#       <td id="T_d399a_row5_col6" class="data row5 col6" >2,061</td>
#       <td id="T_d399a_row5_col7" class="data row5 col7" >7</td>
#     </tr>
#     <tr>
#       <th id="T_d399a_level0_row6" class="row_heading level0 row6" >max</th>
#       <td id="T_d399a_row6_col0" class="data row6 col0" >12.45★</td>
#       <td id="T_d399a_row6_col1" class="data row6 col1" >403.90pp</td>
#       <td id="T_d399a_row6_col2" class="data row6 col2" >101.92%</td>
#       <td id="T_d399a_row6_col3" class="data row6 col3" >16.30</td>
#       <td id="T_d399a_row6_col4" class="data row6 col4" >25</td>
#       <td id="T_d399a_row6_col5" class="data row6 col5" >567</td>
#       <td id="T_d399a_row6_col6" class="data row6 col6" >5,525</td>
#       <td id="T_d399a_row6_col7" class="data row6 col7" >66</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0dd63_ caption {
#   text-align: lett;
#   font-size: 150%;
#   border-bottom: 1px solid;
# }
# </style>
# <table id="T_0dd63_" class="dataframe">
#   <caption>Target vs My Eat Range</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Stars</th>
#       <th class="col_heading level0 col1" >Nps</th>
#       <th class="col_heading level0 col2" >Njs</th>
#       <th class="col_heading level0 col3" >Player</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0dd63_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0dd63_row0_col0" class="data row0 col0" >7.2-9.8★</td>
#       <td id="T_0dd63_row0_col1" class="data row0 col1" >6.5-10.0</td>
#       <td id="T_0dd63_row0_col2" class="data row0 col2" >19-22</td>
#       <td id="T_0dd63_row0_col3" class="data row0 col3" >Target</td>
#     </tr>
#     <tr>
#       <th id="T_0dd63_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0dd63_row1_col0" class="data row1 col0" >7.1-8.2★</td>
#       <td id="T_0dd63_row1_col1" class="data row1 col1" >5.8-8.4</td>
#       <td id="T_0dd63_row1_col2" class="data row1 col2" >18-21</td>
#       <td id="T_0dd63_row1_col3" class="data row1 col3" >hatopop</td>
#     </tr>
#   </tbody>
# </table>

# %%
#@title Playlist Simulaton (Target)
#@markdown ---
#@markdown <h4>Enable</h4>
download_playlist_is_enable = True #@param {type:"boolean"}
result_view_type = "detail" #@param ["simple", "normal", "detail"]
#@markdown ---
#@markdown <h4>Expected Parameters</h4>
# filtered_days_max = 90 #@param {type:"slider", min:1, max:90, step:1}
pp_eat_target = "pred" #@param ["pred", "max", "mean", "improved"]
sort_col = "+PP" #@param ["Stars", "+PP", "PP_Diff", "Acc_Diff", "PP_mean", "PP_max", "N"]
# pred_fc_is_enable = True #@param {type:"boolean"}
pred_miss_reduced = 2 #@param {type:"slider", min:0, max:100, step:1}
reset_index_is_enable = True #param {type:"boolean"}
acc_improved = 0.5 #@param {type:"slider", min:0.1, max:5, step:0.1}
#@markdown ---
#@markdown <h4>Target Filters</h4>

filtered_target_N_min = 4 #@param {type:"slider", min:1, max:20, step:1}
filtered_target_mean_pp_min = 0 #param {type:"slider", min:0, max:1000, step:10}
filtered_plus_pp_min = 0 #@param {type:"slider", min:-1, max:90, step:1}
filtered_my_star_range_is_enable = False #@param {type:"boolean"}
not_cleared_is_include = False #@param {type:"boolean"}

# -----------------------------
# get target_players score
# -----------------------------
df_target_scores_simu = df_target_scores.copy()

df_target_scores_simu = df_target_scores_simu[(1==1)
    &(df_target_scores_simu['Stars'] >= start_star)
    &(df_target_scores_simu['Stars'] <= end_star)
    ]

# 集計
df_result = df_target_scores_simu.groupby(['Hash','SongName','LevelAuthor','Difficulty','Stars']).agg({'Stars': ['count'],'Acc': ['max','mean', 'std'],'PP': ['max','mean', 'std']})

# カラム名の整形
df_result.columns = [f'{col[0]}_{col[1]}' for col in df_result.columns]

df_result = df_result[df_result['Stars_count'] >= filtered_target_N_min]

df_result = df_result[df_result['PP_mean'] >= filtered_target_mean_pp_min]

df_result = df_result.sort_values(by=['PP_mean'], ascending=False)


df_result = pd.merge(df_result, df_scores[['Hash','SongName','LevelAuthor', 'Difficulty','Stars','Acc','PP']], on=['Hash', 'SongName','LevelAuthor','Difficulty', 'Stars'], how='left')

result_cols = ['Hash', 'SongName','LevelAuthor','Difficulty', 'Stars', 'Stars_count', 'Acc','Acc_max',
       'Acc_mean', 'Acc_std', 'PP', 'PP_max', 'PP_mean', 'PP_std']

df_result = df_result[result_cols]

# ---------------------------
# Acc, PPの予測処理
# ---------------------------
df_target_result = df_result.copy()
# 過去のプレイデータからAccを予測しPPを算出
if pp_eat_target == "pred":
    df_target_set = pd.merge(df_result, df_scores, on=['Hash','Stars'], how='left')

    # x_pred = df_target_set[['Stars','Njs','Notes', 'Bombs', 'Obstacles', 'Nps','Length','Seconds', 'Errors', 'Warns', 'Resets']]
    x_pred = df_target_set[cols_pred]

    if pred_days_dependent_is_enable :
        x_pred['Days'] = 0

    if pred_miss_dependent_is_enable:
        df_target_result['Miss'] = x_pred['Miss']

        def func_miss_reduced(x):
            before_miss = x
            if before_miss - pred_miss_reduced <= 0:
                return 0 
            else:
                return before_miss - pred_miss_reduced

        x_pred['Miss'] = x_pred['Miss'].apply(func_miss_reduced)
        df_target_result['Miss_pred'] = x_pred['Miss']

    y_pred = model.predict(x_pred)

    # 予測結果をデータフレームに追加
    df_target_result['Acc_pred'] = y_pred

    df_target_result['PP_pred'] = df_target_result[['Stars', 'Acc_pred']].apply(func_star_acc_to_pp, axis=1)

# ---------------------------
# Accを改善する場合の増分計算
# ---------------------------
def func_acc_improved(x):
    if x > 0:
        return x + acc_improved
    else:
        return x + acc_improved

df_target_result['Acc_improved'] =  df_target_result['Acc'].apply(func_acc_improved)
df_target_result['PP_improved'] = df_target_result[['Stars', 'Acc_improved']].apply(func_star_acc_to_pp, axis=1)

# ---------------------------
# Acc, PPの増分計算
# ---------------------------
# my_ppとpp_meanの差分を計算する
df_target_result['Acc_diff'] =  df_target_result['Acc_{}'.format(pp_eat_target)] - df_target_result['Acc'].fillna(0)

# my_ppとpp_meanの差分を計算する
df_target_result['PP_diff'] =  df_target_result['PP_{}'.format(pp_eat_target)] - df_target_result['PP'].fillna(0)

# 合計値算出
def func_pp_target_mogmog(x):
    before_pp = x[0]
    eat_pp = x[1]
    list_target_pp = df_scores['PP'].to_list()
    n_count = 0
    t_pp = 0
    weight = "-"

    # while t_pp < target_total_pp:
    if before_pp in list_target_pp:
        list_target_pp.remove(before_pp)
    list_target_pp.append(eat_pp)
    list_target_pp.sort(reverse=True)
    total_pp = [list_target_pp[i] * 0.965 ** i for i in range(len(list_target_pp))]
    t_pp = sum(total_pp)
    return (t_pp - now_pp)

df_target_result['+PP'] = df_target_result[['PP','PP_{}'.format(pp_eat_target)]].apply(func_pp_target_mogmog, axis=1, result_type='expand')


# ---------------------------
# 表示整理
# ---------------------------
df_target_result['N'] = df_target_result['Stars_count']
if not_cleared_is_include:
    df_target_result = df_target_result.fillna(0)
else:
    df_target_result = df_target_result.dropna()

def func_acc_stats(x):
    mean_val = x[0]
    std_val = x[1]
    return "{:,.02f} ± {:,.02f}%".format(mean_val, std_val)

df_target_result['Acc_Stats'] = df_target_result[['Acc_mean','Acc_std']].apply(func_acc_stats, axis=1, result_type='expand')


def func_pp_stats(x):
    mean_val = x[0]
    std_val = x[1]
    return "{:,.01f} ± {:,.01f}pp".format(mean_val, std_val)

df_target_result['PP_Stats'] = df_target_result[['PP_mean','PP_std']].apply(func_pp_stats, axis=1, result_type='expand')

def func_acc_expected(x):
    before_val = x[0]
    after_val = x[1]
    plus_val = x[2]
    return "{:,.02f} -> {:,.02f}% ({:+,.02f}%)".format(before_val, after_val, plus_val)

df_target_result['Acc_Expected'] = df_target_result[['Acc','Acc_{}'.format(pp_eat_target),'Acc_diff']].apply(func_acc_expected, axis=1, result_type='expand')

def func_pp_expected(x):
    before_val = x[0]
    after_val = x[1]
    plus_val = x[2]
    return "{:,.01f} -> {:,.01f}pp ({:+,.02f}pp)".format(before_val, after_val, plus_val)

df_target_result['PP_Expected'] = df_target_result[['PP','PP_{}'.format(pp_eat_target),'+PP']].apply(func_pp_expected, axis=1, result_type='expand')

col_result_format = ['SongName','LevelAuthor','Difficulty','Stars','N','Acc_Stats','PP_Stats','Miss_Assumed','Acc_Expected','PP_Expected','+PP']

style_simulator2_format = {
        "no": "{:,.0f}",
        "Stars": "{:,.2f}★",
        "PP": "{:,.1f}pp",
        "PP_max": "{:,.1f}pp",
        "PP_mean": "{:,.1f}pp",
        "PP_std": "{:,.2f}pp",
        "PP_pred": "{:,.1f}pp",
        "+PP": "{:+,.2f}pp",
        "Acc": "{:,.2f}%",
        "Acc_max": "{:,.2f}%",
        "Acc_mean": "{:,.2f}%",
        "Acc_std": "{:,.2f}%",
        "Acc_pred": "{:,.2f}%",
        "total_pp": "{:,.2f}pp",
        # "pp(n)": "{:,.2f}pp",
        "total_pp(n)": "{:,.2f}pp",
        "+pp(n)": "{:+,.2f}pp",
        "Njs": "{:,.0f}",
        "Notes": "{:,.0f}",
}

def func_miss_assumed(x):
    before_val = x[0]
    after_val = x[1]
    return "{:,.0f} -> {:,.0f}".format(before_val, after_val)

df_target_result['Miss_Assumed'] = df_target_result[['Miss','Miss_pred']].apply(func_miss_assumed, axis=1, result_type='expand')

# 最終フィルタ(starベース)
if filtered_my_star_range_is_enable:
    df_target_result = df_target_result[(1==1)
        & (df_target_result['Stars'] >= start_star)
        & (df_target_result['Stars'] <= end_star)
    ]

# 最終フィルタ(+ppベース)
if filtered_plus_pp_min >= 0:
    df_target_result = df_target_result[(1==1)
        & (df_target_result['+PP'] >= filtered_plus_pp_min)
    ]


# 最終フィルタ(start_pp, end_ppベース)
df_target_result = df_target_result[(1==1)
    & (df_target_result['PP_{}'.format(pp_eat_target)] >= start_pp)
    & (df_target_result['PP_{}'.format(pp_eat_target)] <= end_pp)
]

# -----------------------------
# playlist download
# -----------------------------
if download_playlist_is_enable:
    # playlistの出力
    songs = []
    for i, x in df_target_result.iterrows():
        songs += [{
            "songName": x["SongName"],
            "levelAuthorName": x["LevelAuthor"],
            "hash": x["Hash"],
            "levelid": f"custom_level_{x['Hash']}",
            "difficulties": [
                {
                    "characteristic": "Standard",
                    "name": x["Difficulty"]
                }
            ]
        }]

    playlist = {
        "playlistTitle": "{}_{}Scores".format(tz_ja.strftime("%Y.%m.%d"), "PPSimulator"),
        "playlistAuthor": "hatopop",
        "songs": songs
    }

    song_playlist_path = r"{}/{}_playlist_{}.json".format(data_path, "PPSimulator", datetime.now().strftime("%Y%m%d"))

    with open(song_playlist_path, "w") as f:
        json.dump(playlist, f)

        files.download(song_playlist_path)

    print("Playlistを出力しました. 曲数:{}.".format(len(df_target_result)))

# df_result.style.set_table_styles(styles_data)#.background_gradient(subset=['PP_diff'], cmap='coolwarm')

# -----------------------------
# 表示
# -----------------------------
df_target_result = df_target_result.sort_values(sort_col, ascending=False)

if reset_index_is_enable:
    df_target_result = df_target_result.reset_index(drop=True)


caption_styles = [dict(selector="caption",
                       props=[
                              ("text-align", "lett"),
                              ("font-size", "150%"),
                              ("border-bottom", "1px solid"),
                              ]
                       )
                  ]

if (pp_eat_target == "pred") and (pred_miss_reduced > 0):
    caption_msg = "Playlist Simulation (now:{:,.2f}pp->target:{:,.2f}pp) - method:{}(-{} misses) - {} - {}".format(
        now_pp, target_total_pp, pp_eat_target, pred_miss_reduced, tz_ja.strftime("%Y.%m.%d"), df_info["name"][0])
else:
    caption_msg = "Playlist Simulation (now:{:,.2f}pp->target:{:,.2f}pp) - method:{} - {} - {}".format(
        now_pp, target_total_pp, pp_eat_target, tz_ja.strftime("%Y.%m.%d"), df_info["name"][0])

df_target_result[col_result_format].style.set_table_styles(styles_data
                                                ).background_gradient(subset=['+PP'], cmap='coolwarm'
                                                ).format(style_simulator2_format
                                                # ).set_caption("[ScoreSaber] Playlist Simulation "
                                                ).set_caption(caption_msg #"Playlist Simulation (now:{:,.2f}pp->target:{:,.2f}pp) - method:{} - {} - {}".format(now_pp, target_total_pp, pp_eat_target, tz_ja.strftime("%Y.%m.%d"), df_info["name"][0])
                                                ).set_table_styles(caption_styles)

cols_song_info = ['Id','Hash', 'Difficulty', 'Stars','Njs','Notes', 'Bombs', 'Obstacles', 'Nps','Length','Seconds', 'Errors', 'Warns', 'Resets']
merged_df = pd.merge(df_target_result, df_rankmap_data[cols_song_info], on=['Hash', 'Difficulty'], how='left', suffixes=('', '_drop'))

def convert_seconds_to_minutes_and_seconds(seconds):
    minutes = int(seconds // 60)
    seconds = int(seconds % 60)
    return f"{minutes}m{seconds}s"

merged_df['Duration'] = merged_df['Seconds'].apply(convert_seconds_to_minutes_and_seconds)

cols_normal = ['Id','SongName', 'LevelAuthor', 'Difficulty', 'Stars','Nps','Njs','Duration','Notes',"N","Acc_Stats","PP_Stats","Miss_Assumed","Acc_Expected","PP_Expected","+PP"]
cols_detail = ['Id','SongName', 'LevelAuthor', 'Difficulty', 'Stars','Nps','Njs','Duration','Notes','Bombs','Obstacles','Errors','Warns', 'Resets',"N","Acc_Stats","PP_Stats","Miss_Assumed","Acc_Expected","PP_Expected","+PP"]


merged_df = merged_df.loc[:, ~merged_df.columns.str.endswith('_drop')]

if result_view_type == "simple":
    cols_result = col_result_format
elif result_view_type == "normal":
    cols_result = cols_normal
elif result_view_type == "detail":
    cols_result = cols_detail
else:
    cols_result = col_result_format


merged_df[cols_result].style.set_table_styles(styles_data
                                                ).background_gradient(subset=['+PP'], cmap='coolwarm'
                                                ).format(style_simulator2_format
                                                ).set_caption(caption_msg #"Playlist Simulation (now:{:,.2f}pp->target:{:,.2f}pp) - method:{} - {} - {}".format(now_pp, target_total_pp, pp_eat_target, tz_ja.strftime("%Y.%m.%d"), df_info["name"][0])
                                                ).set_table_styles(caption_styles)
# Out:
# Playlistを出力しました. 曲数:23.
# <style type="text/css">
# #T_8cc88_ caption {
#   text-align: lett;
#   font-size: 150%;
#   border-bottom: 1px solid;
# }
# #T_8cc88_row0_col20 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8cc88_row1_col20 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_8cc88_row2_col20 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_8cc88_row3_col20 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_8cc88_row4_col20 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_8cc88_row5_col20, #T_8cc88_row6_col20 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_8cc88_row7_col20 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_8cc88_row8_col20 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_8cc88_row9_col20 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_8cc88_row10_col20 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_8cc88_row11_col20 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_8cc88_row12_col20 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_8cc88_row13_col20 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_8cc88_row14_col20 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_8cc88_row15_col20 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_8cc88_row16_col20 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_8cc88_row17_col20 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_8cc88_row18_col20 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_8cc88_row19_col20 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_8cc88_row20_col20, #T_8cc88_row21_col20 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_8cc88_row22_col20 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8cc88_" class="dataframe">
#   <caption>Playlist Simulation (now:8,664.88pp->target:9,000.00pp) - method:pred(-2 misses) - 2023.03.10 - hatopop</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Id</th>
#       <th class="col_heading level0 col1" >SongName</th>
#       <th class="col_heading level0 col2" >LevelAuthor</th>
#       <th class="col_heading level0 col3" >Difficulty</th>
#       <th class="col_heading level0 col4" >Stars</th>
#       <th class="col_heading level0 col5" >Nps</th>
#       <th class="col_heading level0 col6" >Njs</th>
#       <th class="col_heading level0 col7" >Duration</th>
#       <th class="col_heading level0 col8" >Notes</th>
#       <th class="col_heading level0 col9" >Bombs</th>
#       <th class="col_heading level0 col10" >Obstacles</th>
#       <th class="col_heading level0 col11" >Errors</th>
#       <th class="col_heading level0 col12" >Warns</th>
#       <th class="col_heading level0 col13" >Resets</th>
#       <th class="col_heading level0 col14" >N</th>
#       <th class="col_heading level0 col15" >Acc_Stats</th>
#       <th class="col_heading level0 col16" >PP_Stats</th>
#       <th class="col_heading level0 col17" >Miss_Assumed</th>
#       <th class="col_heading level0 col18" >Acc_Expected</th>
#       <th class="col_heading level0 col19" >PP_Expected</th>
#       <th class="col_heading level0 col20" >+PP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8cc88_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8cc88_row0_col0" class="data row0 col0" >15b6e</td>
#       <td id="T_8cc88_row0_col1" class="data row0 col1" >Bassline Yatteru? w</td>
#       <td id="T_8cc88_row0_col2" class="data row0 col2" >Joshabi & altrewin</td>
#       <td id="T_8cc88_row0_col3" class="data row0 col3" >Expert</td>
#       <td id="T_8cc88_row0_col4" class="data row0 col4" >7.62★</td>
#       <td id="T_8cc88_row0_col5" class="data row0 col5" >7.50</td>
#       <td id="T_8cc88_row0_col6" class="data row0 col6" >21</td>
#       <td id="T_8cc88_row0_col7" class="data row0 col7" >4m39s</td>
#       <td id="T_8cc88_row0_col8" class="data row0 col8" >2,093</td>
#       <td id="T_8cc88_row0_col9" class="data row0 col9" >20</td>
#       <td id="T_8cc88_row0_col10" class="data row0 col10" >251</td>
#       <td id="T_8cc88_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_8cc88_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_8cc88_row0_col13" class="data row0 col13" >5</td>
#       <td id="T_8cc88_row0_col14" class="data row0 col14" >4</td>
#       <td id="T_8cc88_row0_col15" class="data row0 col15" >93.89 ± 1.08%</td>
#       <td id="T_8cc88_row0_col16" class="data row0 col16" >300.5 ± 19.5pp</td>
#       <td id="T_8cc88_row0_col17" class="data row0 col17" >2 -> 0</td>
#       <td id="T_8cc88_row0_col18" class="data row0 col18" >94.61 -> 95.71% (+1.10%)</td>
#       <td id="T_8cc88_row0_col19" class="data row0 col19" >313.4 -> 345.9pp (+30.08pp)</td>
#       <td id="T_8cc88_row0_col20" class="data row0 col20" >+30.08pp</td>
#     </tr>
#     <tr>
#       <th id="T_8cc88_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8cc88_row1_col0" class="data row1 col0" >87aa</td>
#       <td id="T_8cc88_row1_col1" class="data row1 col1" >Internet bitch</td>
#       <td id="T_8cc88_row1_col2" class="data row1 col2" >Light Ai & ExUnReal</td>
#       <td id="T_8cc88_row1_col3" class="data row1 col3" >ExpertPlus</td>
#       <td id="T_8cc88_row1_col4" class="data row1 col4" >7.93★</td>
#       <td id="T_8cc88_row1_col5" class="data row1 col5" >9.02</td>
#       <td id="T_8cc88_row1_col6" class="data row1 col6" >20</td>
#       <td id="T_8cc88_row1_col7" class="data row1 col7" >4m22s</td>
#       <td id="T_8cc88_row1_col8" class="data row1 col8" >2,372</td>
#       <td id="T_8cc88_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_8cc88_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_8cc88_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_8cc88_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_8cc88_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_8cc88_row1_col14" class="data row1 col14" >6</td>
#       <td id="T_8cc88_row1_col15" class="data row1 col15" >92.82 ± 0.90%</td>
#       <td id="T_8cc88_row1_col16" class="data row1 col16" >293.2 ± 15.4pp</td>
#       <td id="T_8cc88_row1_col17" class="data row1 col17" >3 -> 1</td>
#       <td id="T_8cc88_row1_col18" class="data row1 col18" >93.64 -> 94.84% (+1.19%)</td>
#       <td id="T_8cc88_row1_col19" class="data row1 col19" >307.4 -> 330.7pp (+19.23pp)</td>
#       <td id="T_8cc88_row1_col20" class="data row1 col20" >+19.23pp</td>
#     </tr>
#     <tr>
#       <th id="T_8cc88_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8cc88_row2_col0" class="data row2 col0" >1a57d</td>
#       <td id="T_8cc88_row2_col1" class="data row2 col1" >Outbreak</td>
#       <td id="T_8cc88_row2_col2" class="data row2 col2" >abcbadq</td>
#       <td id="T_8cc88_row2_col3" class="data row2 col3" >Expert</td>
#       <td id="T_8cc88_row2_col4" class="data row2 col4" >7.98★</td>
#       <td id="T_8cc88_row2_col5" class="data row2 col5" >7.45</td>
#       <td id="T_8cc88_row2_col6" class="data row2 col6" >20</td>
#       <td id="T_8cc88_row2_col7" class="data row2 col7" >4m14s</td>
#       <td id="T_8cc88_row2_col8" class="data row2 col8" >1,897</td>
#       <td id="T_8cc88_row2_col9" class="data row2 col9" >13</td>
#       <td id="T_8cc88_row2_col10" class="data row2 col10" >415</td>
#       <td id="T_8cc88_row2_col11" class="data row2 col11" >0</td>
#       <td id="T_8cc88_row2_col12" class="data row2 col12" >0</td>
#       <td id="T_8cc88_row2_col13" class="data row2 col13" >1</td>
#       <td id="T_8cc88_row2_col14" class="data row2 col14" >5</td>
#       <td id="T_8cc88_row2_col15" class="data row2 col15" >92.80 ± 0.68%</td>
#       <td id="T_8cc88_row2_col16" class="data row2 col16" >294.3 ± 11.9pp</td>
#       <td id="T_8cc88_row2_col17" class="data row2 col17" >3 -> 1</td>
#       <td id="T_8cc88_row2_col18" class="data row2 col18" >93.38 -> 94.51% (+1.13%)</td>
#       <td id="T_8cc88_row2_col19" class="data row2 col19" >304.4 -> 326.1pp (+16.69pp)</td>
#       <td id="T_8cc88_row2_col20" class="data row2 col20" >+16.69pp</td>
#     </tr>
#     <tr>
#       <th id="T_8cc88_level0_row3" class="row_heading level0 row3" >3</th>

# %%
#@title Playlist Simulaton (Without Target Player Data)
#@markdown ---
#@markdown <h4>Enable</h4>
download_playlist_is_enable = True #@param {type:"boolean"}

#@markdown ---
#@markdown <h4>Expected Parameters</h4>
# filtered_days_max = 90 #@param {type:"slider", min:1, max:90, step:1}
pp_eat_target = "pred" #@param ["pred", "max", "mean", "improved"]
result_view_type = "normal" #@param ["simple", "normal", "detail"]
sort_col = "+PP" #@param ["Stars", "+PP", "PP_Diff", "Acc_Diff", "PP_mean", "PP_max", "N"]
# pred_fc_is_enable = True #@param {type:"boolean"}
pred_miss_reduced = 2 #@param {type:"slider", min:0, max:100, step:1}
reset_index_is_enable = True #param {type:"boolean"}
acc_improved = 0.5 #@param {type:"slider", min:0.1, max:5, step:0.1}

#@markdown ---
#@markdown <h4>Result Filters</h4>
# filtered_target_N_min = 4 #@param {type:"slider", min:1, max:20, step:1}
filtered_target_mean_pp_min = 0 #param {type:"slider", min:0, max:1000, step:10}
not_cleared_is_include = True #@param {type:"boolean"}
filtered_my_star_range_is_enable = True #@param {type:"boolean"}
filtered_nps = "-" #@param ["-", "Star>Nps Only", "Nps>Star Only"]
filtered_nps_min = 5 #@param {type:"slider", min:0, max:50, step:1}
filtered_nps_max = 15 #@param {type:"slider", min:0, max:50, step:1}
filtered_njs_min = 0 #@param {type:"slider", min:0, max:50, step:1}
filtered_njs_max = 20 #@param {type:"slider", min:0, max:50, step:1}
filtered_notes_min = 0 #@param {type:"slider", min:0, max:10000, step:100}
filtered_notes_max = 4000 #@param {type:"slider", min:0, max:10000, step:100}
filtered_seconds_min = 0 #@param {type:"slider", min:0, max:1200, step:100}
filtered_seconds_max = 300 #@param {type:"slider", min:0, max:1200, step:100}
data_max_size = 50 #@param {type:"slider", min:10, max:1000, step:10}

# -----------------------------
# get target_players score
# -----------------------------

df_result = df_rankmap_data.copy()

import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from scipy import interpolate

# ---------------------------
# Acc, PPの予測処理
# ---------------------------
df_target_result = df_result.copy()
# 過去のプレイデータからAccを予測しPPを算出
if pp_eat_target == "pred":
    df_target_result = pd.merge(df_result, df_scores, on=['Hash','Stars'], how='left', suffixes=('', '_drop'))
    df_target_result = df_target_result.loc[:, ~df_target_result.columns.str.endswith('_drop')]
    x_pred = df_target_result[cols_pred]

    if pred_days_dependent_is_enable :
        x_pred['Days'] = 0

    if pred_miss_dependent_is_enable:
        # df_target_result['Miss'] = x_pred['Miss']
        df_target_result['Miss'] = x_pred['Miss']

        def func_miss_reduced(x):
            before_miss = x
            if before_miss - pred_miss_reduced <= 0:
                return 0 
            else:
                return before_miss - pred_miss_reduced

        x_pred['Miss'] = x_pred['Miss'].apply(func_miss_reduced)
        # df_target_result['Miss_pred'] = x_pred['Miss']
        df_target_result['Miss_pred'] = x_pred['Miss']

    y_pred = model.predict(x_pred)

    # 予測結果をデータフレームに追加
    # df_target_result['Acc_pred'] = y_pred
    # df_target_result['PP_pred'] = df_target_result[['Stars', 'Acc_pred']].apply(func_star_acc_to_pp, axis=1)
    df_target_result['Acc_pred'] = y_pred
    df_target_result['PP_pred'] = df_target_result[['Stars', 'Acc_pred']].apply(func_star_acc_to_pp, axis=1)

# ---------------------------
# Accを改善する場合の増分計算
# ---------------------------
def func_acc_improved(x):
    if x > 0:
        return x + acc_improved
    else:
        return x + acc_improved

df_target_result['Acc_improved'] =  df_target_result['Acc'].apply(func_acc_improved)
df_target_result['PP_improved'] = df_target_result[['Stars', 'Acc_improved']].apply(func_star_acc_to_pp, axis=1)

# ---------------------------
# Acc, PPの増分計算
# ---------------------------
# my_ppとpp_meanの差分を計算する
df_target_result['Acc_diff'] =  df_target_result['Acc_{}'.format(pp_eat_target)] - df_target_result['Acc'].fillna(0)

# my_ppとpp_meanの差分を計算する
df_target_result['PP_diff'] =  df_target_result['PP_{}'.format(pp_eat_target)] - df_target_result['PP'].fillna(0)

# 合計値算出
def func_pp_target_mogmog(x):
    before_pp = x[0]
    eat_pp = x[1]
    list_target_pp = df_scores['PP'].to_list()
    n_count = 0
    t_pp = 0
    weight = "-"

    # while t_pp < target_total_pp:
    if before_pp in list_target_pp:
        list_target_pp.remove(before_pp)
    list_target_pp.append(eat_pp)
    list_target_pp.sort(reverse=True)
    total_pp = [list_target_pp[i] * 0.965 ** i for i in range(len(list_target_pp))]
    t_pp = sum(total_pp)
    return (t_pp - now_pp)

df_target_result['+PP'] = df_target_result[['PP','PP_{}'.format(pp_eat_target)]].apply(func_pp_target_mogmog, axis=1, result_type='expand')


# ---------------------------
# 表示整理
# ---------------------------
# df_target_result['N'] = df_target_result['Stars_count']
if not_cleared_is_include:
    df_target_result = df_target_result.fillna(0)
else:
    df_target_result = df_target_result.dropna()

def func_acc_expected(x):
    before_val = x[0]
    after_val = x[1]
    plus_val = x[2]
    return "{:,.02f} -> {:,.02f}% ({:+,.02f}%)".format(before_val, after_val, plus_val)

df_target_result['Acc_Expected'] = df_target_result[['Acc','Acc_{}'.format(pp_eat_target),'Acc_diff']].apply(func_acc_expected, axis=1, result_type='expand')

def func_pp_expected(x):
    before_val = x[0]
    after_val = x[1]
    plus_val = x[2]
    return "{:,.01f} -> {:,.01f}pp ({:+,.02f}pp)".format(before_val, after_val, plus_val)

df_target_result['PP_Expected'] = df_target_result[['PP','PP_{}'.format(pp_eat_target),'+PP']].apply(func_pp_expected, axis=1, result_type='expand')

col_result_format = ['SongName','LevelAuthor','Difficulty','Stars', 'Miss_Assumed','Acc_Expected','PP_Expected','+PP']

style_simulator2_format = {
        "no": "{:,.0f}",
        "Stars": "{:,.2f}★",
        "PP": "{:,.1f}pp",
        "PP_max": "{:,.1f}pp",
        "PP_mean": "{:,.1f}pp",
        "PP_std": "{:,.2f}pp",
        "PP_pred": "{:,.1f}pp",
        "+PP": "{:+,.2f}pp",
        "Acc": "{:,.2f}%",
        "Acc_max": "{:,.2f}%",
        "Acc_mean": "{:,.2f}%",
        "Acc_std": "{:,.2f}%",
        "Acc_pred": "{:,.2f}%",
        "total_pp": "{:,.2f}pp",
        # "pp(n)": "{:,.2f}pp",
        "total_pp(n)": "{:,.2f}pp",
        "+pp(n)": "{:+,.2f}pp",
        "Njs": "{:,.0f}",
        "Notes": "{:,.0f}",
}

def func_miss_assumed(x):
    before_val = x[0]
    after_val = x[1]
    return "{:,.0f} -> {:,.0f}".format(before_val, after_val)

df_target_result['Miss_Assumed'] = df_target_result[['Miss','Miss_pred']].apply(func_miss_assumed, axis=1, result_type='expand')


# 最終フィルタ(starベース)
if filtered_my_star_range_is_enable:
    df_target_result = df_target_result[(1==1)
        & (df_target_result['Stars'] >= start_star)
        & (df_target_result['Stars'] <= end_star)
    ]


# 最終フィルタ(+ppベース)
if filtered_plus_pp_min >= 0:
    df_target_result = df_target_result[(1==1)
        & (df_target_result['+PP'] >= filtered_plus_pp_min)
    ]


# 最終フィルタ(start_pp, end_ppベース)
df_target_result = df_target_result[(1==1)
    & (df_target_result['PP_{}'.format(pp_eat_target)] >= start_pp)
    & (df_target_result['PP_{}'.format(pp_eat_target)] <= end_pp)
]

# 最終フィルタNps選別
if filtered_nps == "Star>Nps Only":
    df_target_result = df_target_result[(df_target_result['Ranked']==1)
                        & (df_target_result["Stars"] >= df_target_result["Nps"])]
elif filtered_nps == "Nps>Star Only":
    df_target_result = df_target_result[(df_target_result['Ranked']==1)
                        & (df_target_result["Nps"] >= df_target_result["Stars"])]

df_target_result = df_target_result[(df_target_result['Ranked']==1)
                & (df_target_result["Nps"] >= filtered_nps_min)
                & (df_target_result["Nps"] <= filtered_nps_max)
                & (df_target_result["Njs"] >= filtered_njs_min)
                & (df_target_result["Njs"] <= filtered_njs_max)
                & (df_target_result["Notes"] >= filtered_notes_min)
                & (df_target_result["Notes"] <= filtered_notes_max)
                & (df_target_result["Seconds"] >= filtered_seconds_min)
                & (df_target_result["Seconds"] <= filtered_seconds_max)
                ]


# -----------------------------
# playlist download
# -----------------------------
df_target_result = df_target_result.sort_values(sort_col, ascending=False)
df_target_result = df_target_result[:data_max_size]

if download_playlist_is_enable:
    # playlistの出力
    songs = []
    for i, x in df_target_result.iterrows():
        songs += [{
            "songName": x["SongName"],
            "levelAuthorName": x["LevelAuthor"],
            "hash": x["Hash"],
            "levelid": f"custom_level_{x['Hash']}",
            "difficulties": [
                {
                    "characteristic": "Standard",
                    "name": x["Difficulty"]
                }
            ]
        }]

    playlist = {
        "playlistTitle": "{}_{}Scores".format(tz_ja.strftime("%Y.%m.%d"), "npsSimulator"),
        "playlistAuthor": "hatopop",
        "songs": songs
    }

    song_playlist_path = r"{}/{}_playlist_{}.json".format(data_path, "PPSimulator2_AllRankedSong", datetime.now().strftime("%Y%m%d"))

    with open(song_playlist_path, "w") as f:
        json.dump(playlist, f)

        files.download(song_playlist_path)

    print("Playlistを出力しました. 曲数:{}.\n\n".format(len(df_target_result)))

# df_result.style.set_table_styles(styles_data)#.background_gradient(subset=['PP_diff'], cmap='coolwarm')

# -----------------------------
# 表示
# -----------------------------

if reset_index_is_enable:
    df_target_result = df_target_result.reset_index(drop=True)

cols_song_info = ['Id','Hash', 'Difficulty', 'Stars','Njs','Notes', 'Bombs', 'Obstacles', 'Nps','Length','Seconds', 'Errors', 'Warns', 'Resets']
merged_df = pd.merge(df_target_result, df_rankmap_data[cols_song_info], on=['Hash', 'Difficulty'], how='left', suffixes=('', '_drop'))

def convert_seconds_to_minutes_and_seconds(seconds):
    minutes = int(seconds // 60)
    seconds = int(seconds % 60)
    return f"{minutes}m{seconds}s"

merged_df['Duration'] = merged_df['Seconds'].apply(convert_seconds_to_minutes_and_seconds)

cols_normal = ['Id','SongName', 'LevelAuthor', 'Difficulty', 'Stars','Nps','Njs','Duration','Notes',"Miss_Assumed","Acc_Expected","PP_Expected","+PP"]
cols_detail = ['Id','SongName', 'LevelAuthor', 'Difficulty', 'Stars','Nps','Njs','Duration','Notes','Bombs','Obstacles','Errors','Warns', 'Resets',"Miss_Assumed","Acc_Expected","PP_Expected","+PP"]


merged_df = merged_df.loc[:, ~merged_df.columns.str.endswith('_drop')]

if result_view_type == "simple":
    cols_result = col_result_format
elif result_view_type == "normal":
    cols_result = cols_normal
elif result_view_type == "detail":
    cols_result = cols_detail
else:
    cols_result = col_result_format

# caption
if (pp_eat_target == "pred") and (pred_miss_reduced > 0):
    caption_msg = "Playlist Simulation2 - from All - (now:{:,.2f}pp->target:{:,.2f}pp) - method:{}(-{} misses) - {} - {}".format(
        now_pp, target_total_pp, pp_eat_target, pred_miss_reduced, tz_ja.strftime("%Y.%m.%d"), df_info["name"][0])
else:
    caption_msg = "Playlist Simulation2 - from All - (now:{:,.2f}pp->target:{:,.2f}pp) - method:{} - {} - {}".format(
        now_pp, target_total_pp, pp_eat_target, tz_ja.strftime("%Y.%m.%d"), df_info["name"][0])


merged_df[cols_result].style.set_table_styles(styles_data
                                                ).background_gradient(subset=['+PP'], cmap='coolwarm'
                                                ).format(style_simulator2_format
                                                ).set_caption(caption_msg #"Playlist Simulation (now:{:,.2f}pp->target:{:,.2f}pp) - method:{} - {} - {}".format(now_pp, target_total_pp, pp_eat_target, tz_ja.strftime("%Y.%m.%d"), df_info["name"][0])
                                                ).set_table_styles(caption_styles)
# Out:
# Playlistを出力しました. 曲数:50.
# <style type="text/css">
# #T_a92b4_ caption {
#   text-align: lett;
#   font-size: 150%;
#   border-bottom: 1px solid;
# }
# #T_a92b4_row0_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a92b4_row1_col12 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_a92b4_row2_col12 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_a92b4_row3_col12 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_a92b4_row4_col12 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_a92b4_row5_col12 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_a92b4_row6_col12 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_a92b4_row7_col12 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_a92b4_row8_col12 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_a92b4_row9_col12 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_a92b4_row10_col12, #T_a92b4_row11_col12 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_a92b4_row12_col12 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_a92b4_row13_col12 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_a92b4_row14_col12 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_a92b4_row15_col12 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_a92b4_row16_col12, #T_a92b4_row17_col12, #T_a92b4_row18_col12 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_a92b4_row19_col12 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_a92b4_row20_col12 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_a92b4_row21_col12, #T_a92b4_row22_col12 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_a92b4_row23_col12, #T_a92b4_row24_col12 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_a92b4_row25_col12, #T_a92b4_row26_col12 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_a92b4_row27_col12 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_a92b4_row28_col12 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_a92b4_row29_col12 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_a92b4_row30_col12 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_a92b4_row31_col12, #T_a92b4_row32_col12, #T_a92b4_row33_col12 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_a92b4_row34_col12, #T_a92b4_row35_col12 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_a92b4_row36_col12 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_a92b4_row37_col12 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_a92b4_row38_col12, #T_a92b4_row39_col12, #T_a92b4_row40_col12, #T_a92b4_row41_col12 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_a92b4_row42_col12, #T_a92b4_row43_col12, #T_a92b4_row44_col12 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_a92b4_row45_col12, #T_a92b4_row46_col12 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_a92b4_row47_col12, #T_a92b4_row48_col12, #T_a92b4_row49_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a92b4_" class="dataframe">
#   <caption>Playlist Simulation2 - from All - (now:8,664.88pp->target:9,000.00pp) - method:pred(-2 misses) - 2023.03.10 - hatopop</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Id</th>
#       <th class="col_heading level0 col1" >SongName</th>
#       <th class="col_heading level0 col2" >LevelAuthor</th>
#       <th class="col_heading level0 col3" >Difficulty</th>
#       <th class="col_heading level0 col4" >Stars</th>
#       <th class="col_heading level0 col5" >Nps</th>
#       <th class="col_heading level0 col6" >Njs</th>
#       <th class="col_heading level0 col7" >Duration</th>
#       <th class="col_heading level0 col8" >Notes</th>
#       <th class="col_heading level0 col9" >Miss_Assumed</th>
#       <th class="col_heading level0 col10" >Acc_Expected</th>
#       <th class="col_heading level0 col11" >PP_Expected</th>
#       <th class="col_heading level0 col12" >+PP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a92b4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a92b4_row0_col0" class="data row0 col0" >23cfc</td>
#       <td id="T_a92b4_row0_col1" class="data row0 col1" >HUGE W</td>
#       <td id="T_a92b4_row0_col2" class="data row0 col2" >Joshabi</td>
#       <td id="T_a92b4_row0_col3" class="data row0 col3" >ExpertPlus</td>
#       <td id="T_a92b4_row0_col4" class="data row0 col4" >8.02★</td>
#       <td id="T_a92b4_row0_col5" class="data row0 col5" >7.64</td>
#       <td id="T_a92b4_row0_col6" class="data row0 col6" >19</td>
#       <td id="T_a92b4_row0_col7" class="data row0 col7" >4m2s</td>
#       <td id="T_a92b4_row0_col8" class="data row0 col8" >1,852</td>
#       <td id="T_a92b4_row0_col9" class="data row0 col9" >1 -> 0</td>
#       <td id="T_a92b4_row0_col10" class="data row0 col10" >93.07 -> 94.73% (+1.65%)</td>
#       <td id="T_a92b4_row0_col11" class="data row0 col11" >300.1 -> 332.2pp (+24.61pp)</td>
#       <td id="T_a92b4_row0_col12" class="data row0 col12" >+24.61pp</td>
#     </tr>
#     <tr>
#       <th id="T_a92b4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a92b4_row1_col0" class="data row1 col0" >1b0ab</td>
#       <td id="T_a92b4_row1_col1" class="data row1 col1" >Android Girl</td>
#       <td id="T_a92b4_row1_col2" class="data row1 col2" >Uninstaller</td>
#       <td id="T_a92b4_row1_col3" class="data row1 col3" >Expert</td>
#       <td id="T_a92b4_row1_col4" class="data row1 col4" >7.80★</td>
#       <td id="T_a92b4_row1_col5" class="data row1 col5" >5.72</td>
#       <td id="T_a92b4_row1_col6" class="data row1 col6" >18</td>
#       <td id="T_a92b4_row1_col7" class="data row1 col7" >3m25s</td>
#       <td id="T_a92b4_row1_col8" class="data row1 col8" >1,176</td>
#       <td id="T_a92b4_row1_col9" class="data row1 col9" >2 -> 0</td>
#       <td id="T_a92b4_row1_col10" class="data row1 col10" >93.84 -> 95.16% (+1.32%)</td>
#       <td id="T_a92b4_row1_col11" class="data row1 col11" >305.8 -> 333.6pp (+23.03pp)</td>
#       <td id="T_a92b4_row1_col12" class="data row1 col12" >+23.03pp</td>
#     </tr>
#     <tr>
#       <th id="T_a92b4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a92b4_row2_col0" class="data row2 col0" >87aa</td>
#       <td id="T_a92b4_row2_col1" class="data row2 col1" >Internet bitch</td>
#       <td id="T_a92b4_row2_col2" class="data row2 col2" >Light Ai & ExUnReal</td>
#       <td id="T_a92b4_row2_col3" class="data row2 col3" >ExpertPlus</td>
#       <td id="T_a92b4_row2_col4" class="data row2 col4" >7.93★</td>
#       <td id="T_a92b4_row2_col5" class="data row2 col5" >9.02</td>
#       <td id="T_a92b4_row2_col6" class="data row2 col6" >20</td>
#       <td id="T_a92b4_row2_col7" class="data row2 col7" >4m22s</td>
#       <td id="T_a92b4_row2_col8" class="data row2 col8" >2,372</td>
#       <td id="T_a92b4_row2_col9" class="data row2 col9" >3 -> 1</td>
#       <td id="T_a92b4_row2_col10" class="data row2 col10" >93.64 -> 94.84% (+1.19%)</td>
#       <td id="T_a92b4_row2_col11" class="data row2 col11" >307.4 -> 330.7pp (+19.23pp)</td>
#       <td id="T_a92b4_row2_col12" class="data row2 col12" >+19.23pp</td>
#     </tr>
#     <tr>
#       <th id="T_a92b4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a92b4_row3_col0" class="data row3 col0" >1a57d</td>
#       <td id="T_a92b4_row3_col1" class="data row3 col1" >Outbreak</td>
#       <td id="T_a92b4_row3_col2" class="data row3 col2" >abcbadq</td>
#       <td id="T_a92b4_row3_col3" class="data row3 col3" >Expert</td>
#       <td id="T_a92b4_row3_col4" class="data row3 col4" >7.98★</td>
#       <td id="T_a92b4_row3_col5" class="data row3 col5" >7.45</td>
#       <td id="T_a92b4_row3_col6" class="data row3 col6" >20</td>
#       <td id="T_a92b4_row3_col7" class="data row3 col7" >4m14s</td>
#       <td id="T_a92b4_row3_col8" class="data row3 col8" >1,897</td>
#       <td id="T_a92b4_row3_col9" class="data row3 col9" >3 -> 1</td>
#       <td id="T_a92b4_row3_col10" class="data row3 col10" >93.38 -> 94.51% (+1.13%)</td>
#       <td id="T_a92b4_row3_col11" class="data row3 col11" >304.4 -> 326.1pp (+16.69pp)</td>
#       <td id="T_a92b4_row3_col12" class="data row3 col12" >+1
